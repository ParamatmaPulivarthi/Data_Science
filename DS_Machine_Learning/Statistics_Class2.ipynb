# %% [markdown]
# # Groupby

# %%
#Groupby, agg, sum,count,mean,median,std,var
# one-variable, two-variable & multiple variables
#cross tabulation,frequency tables
#df.groupby().[].agg()

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\ppulivarthi\AV_Hackthons\HR_Analytics\train_LZdllcl.csv")

# %%
df=pd.read_csv(r"C:\Users\ppulivarthi\AV_Hackthons\Janatahack Healthcare Analytics II\train.csv")

# %%
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# ...

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
df.groupby("column variable")[""].mathematical
df.groupby("column variable")[""].agg()

# %%
# df.head()
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
df.groupby('Type of Admission')['Severity of Illness'].count()
# Out:
# Type of Admission
# Emergency    117676
# Trauma       152261
# Urgent        48501
# Name: Severity of Illness, dtype: int64

# %%
df.groupby('Type of Admission').agg({ 'Severity of Illness' : ["count"]} )
# Out:
#                   Severity of Illness
#                                 count
# Type of Admission
# Emergency                      117676
# Trauma                         152261
# Urgent                          48501

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
#'Type of Admission' wise,'Severity of Illness' wise 'Admission_Deposit' statistics

# %%
df.groupby(['Type of Admission','Severity of Illness'])['Admission_Deposit'].sum()
# Out:
# Type of Admission  Severity of Illness
# Emergency          Extreme                 91551256.0
#                    Minor                  173179612.0
#                    Moderate               296386028.0
# Trauma             Extreme                140229814.0
#                    Minor                  187225361.0
#                    Moderate               431816584.0
# Urgent             Extreme                 37522072.0
#                    Minor                   67430058.0
#                    Moderate               128875290.0
# Name: Admission_Deposit, dtype: float64

# %%
df.groupby(['Type of Admission','Severity of Illness']).agg({"Admission_Deposit" : ["count","sum","mean","median","std","skew"]})
# Out:
#                                       Admission_Deposit               \
#                                                   count          sum
# Type of Admission Severity of Illness
# Emergency         Extreme                         19844   91551256.0
#                   Minor                           35356  173179612.0
#                   Moderate                        62476  296386028.0
# Trauma            Extreme                         28837  140229814.0
#                   Minor                           36800  187225361.0
#                   Moderate                        86624  431816584.0
# Urgent            Extreme                          8042   37522072.0
#                   Minor                           13716   67430058.0
#                   Moderate                        26743  128875290.0
#
#                                                                          \
#                                               mean  median          std
# ...

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
df.groupby(['Type of Admission','Severity of Illness']).agg({"Admission_Deposit" : ["count","sum","mean","median","std","skew"], 'Visitors with Patient': ["mean","std","skew"] })
# Out:
#                                       Admission_Deposit               \
#                                                   count          sum
# Type of Admission Severity of Illness
# Emergency         Extreme                         19844   91551256.0
#                   Minor                           35356  173179612.0
#                   Moderate                        62476  296386028.0
# Trauma            Extreme                         28837  140229814.0
#                   Minor                           36800  187225361.0
#                   Moderate                        86624  431816584.0
# Urgent            Extreme                          8042   37522072.0
#                   Minor                           13716   67430058.0
#                   Moderate                        26743  128875290.0
#
#                                                                          \
#                                               mean  median          std
# ...

# %%
#filter columns by data types select_dtypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   Hospital_type_code                 318438 non-null  object
#  3   City_Code_Hospital                 318438 non-null  int64
#  4   Hospital_region_code               318438 non-null  object
#  5   Available Extra Rooms in Hospital  318438 non-null  int64
#  6   Department                         318438 non-null  object
#  7   Ward_Type                          318438 non-null  object
#  8   Ward_Facility_Code                 318438 non-null  object
#  9   Bed Grade                          318325 non-null  float64
#  10  patientid                          318438 non-null  int64
# ...

# %%
df_char=df.select_dtypes(include='object')

# %%
df_char.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Hospital_type_code    318438 non-null  object
#  1   Hospital_region_code  318438 non-null  object
#  2   Department            318438 non-null  object
#  3   Ward_Type             318438 non-null  object
#  4   Ward_Facility_Code    318438 non-null  object
#  5   Type of Admission     318438 non-null  object
#  6   Severity of Illness   318438 non-null  object
#  7   Age                   318438 non-null  object
#  8   Stay                  318438 non-null  object
# dtypes: object(9)
# memory usage: 21.9+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   Hospital_type_code                 318438 non-null  object
#  3   City_Code_Hospital                 318438 non-null  int64
#  4   Hospital_region_code               318438 non-null  object
#  5   Available Extra Rooms in Hospital  318438 non-null  int64
#  6   Department                         318438 non-null  object
#  7   Ward_Type                          318438 non-null  object
#  8   Ward_Facility_Code                 318438 non-null  object
#  9   Bed Grade                          318325 non-null  float64
#  10  patientid                          318438 non-null  int64
# ...

# %%
df_numeric=df.select_dtypes(include=[np.number])

# %%
df_numeric_int=df.select_dtypes(include='int64')
df_numeric_float=df.select_dtypes(include='float64')

# %%
df_numeric_float.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 3 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Bed Grade          318325 non-null  float64
#  1   City_Code_Patient  313906 non-null  float64
#  2   Admission_Deposit  318438 non-null  float64
# dtypes: float64(3)
# memory usage: 7.3 MB

# %%
df_numeric_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   City_Code_Hospital                 318438 non-null  int64
#  3   Available Extra Rooms in Hospital  318438 non-null  int64
#  4   patientid                          318438 non-null  int64
#  5   Visitors with Patient              318438 non-null  int64
# dtypes: int64(6)
# memory usage: 14.6 MB

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 9 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   City_Code_Hospital                 318438 non-null  int64
#  3   Available Extra Rooms in Hospital  318438 non-null  int64
#  4   Bed Grade                          318325 non-null  float64
#  5   patientid                          318438 non-null  int64
#  6   City_Code_Patient                  313906 non-null  float64
#  7   Visitors with Patient              318438 non-null  int64
#  8   Admission_Deposit                  318438 non-null  float64
# dtypes: float64(3), int64(6)
# memory usage: 21.9 MB

# %%
#Bivariate:  pivot,corr(method=pearson/spearman),pivot(index,columns= values=)
# pd.pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False)

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
pd.pivot_table(df,values='Admission_Deposit',index='Type of Admission',columns='Severity of Illness',aggfunc=np.sum)
# Out:
# Severity of Illness      Extreme        Minor     Moderate
# Type of Admission
# Emergency             91551256.0  173179612.0  296386028.0
# Trauma               140229814.0  187225361.0  431816584.0
# Urgent                37522072.0   67430058.0  128875290.0

# %%
pd.pivot_table(df,values='Admission_Deposit',index=['Type of Admission','Severity of Illness'],aggfunc=np.sum)
# Out:
#                                        Admission_Deposit
# Type of Admission Severity of Illness
# Emergency         Extreme                     91551256.0
#                   Minor                      173179612.0
#                   Moderate                   296386028.0
# Trauma            Extreme                    140229814.0
#                   Minor                      187225361.0
#                   Moderate                   431816584.0
# Urgent            Extreme                     37522072.0
#                   Minor                       67430058.0
#                   Moderate                   128875290.0

# %%
pd.pivot_table(df,values='Admission_Deposit',index=['Type of Admission','Severity of Illness'],aggfunc=[np.sum,np.mean])
# Out:
#                                                     sum              mean
#                                       Admission_Deposit Admission_Deposit
# Type of Admission Severity of Illness
# Emergency         Extreme                    91551256.0       4613.548478
#                   Minor                     173179612.0       4898.167553
#                   Moderate                  296386028.0       4743.998143
# Trauma            Extreme                   140229814.0       4862.843361
#                   Minor                     187225361.0       5087.645679
#                   Moderate                  431816584.0       4984.953177
# Urgent            Extreme                    37522072.0       4665.763740
#                   Minor                      67430058.0       4916.160542
#                   Moderate                  128875290.0       4819.028905

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
pd.pivot_table(df,values=['Admission_Deposit','Visitors with Patient'],index=['Type of Admission','Severity of Illness'],aggfunc=[np.sum,np.mean,np.std])
# Out:
#                                                     sum                        \
#                                       Admission_Deposit Visitors with Patient
# Type of Admission Severity of Illness
# Emergency         Extreme                    91551256.0                 72753
#                   Minor                     173179612.0                118248
#                   Moderate                  296386028.0                217885
# Trauma            Extreme                   140229814.0                 97494
#                   Minor                     187225361.0                115307
#                   Moderate                  431816584.0                280301
# Urgent            Extreme                    37522072.0                 24881
#                   Minor                      67430058.0                 39691
#                   Moderate                  128875290.0                 79222
#
# ...

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 9 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   City_Code_Hospital                 318438 non-null  int64
#  3   Available Extra Rooms in Hospital  318438 non-null  int64
#  4   Bed Grade                          318325 non-null  float64
#  5   patientid                          318438 non-null  int64
#  6   City_Code_Patient                  313906 non-null  float64
#  7   Visitors with Patient              318438 non-null  int64
#  8   Admission_Deposit                  318438 non-null  float64
# dtypes: float64(3), int64(6)
# memory usage: 21.9 MB

# %%
df_numeric.corr()
# Out:
#                                     case_id  Hospital_code  \
# case_id                            1.000000      -0.043023
# Hospital_code                     -0.043023       1.000000
# City_Code_Hospital                -0.011352       0.128294
# Available Extra Rooms in Hospital  0.042580      -0.059638
# Bed Grade                          0.013702      -0.013739
# patientid                         -0.004150       0.002291
# City_Code_Patient                  0.065196      -0.015530
# Visitors with Patient              0.001309      -0.028500
# Admission_Deposit                 -0.045972       0.045446
#
#                                    City_Code_Hospital  \
# case_id                                     -0.011352
# Hospital_code                                0.128294
# City_Code_Hospital                           1.000000
# Available Extra Rooms in Hospital           -0.045771
# Bed Grade                                   -0.049309
# ...

# %%
df=pd.read_csv(r"C:\Users\ppulivarthi\AV_Hackthons\HR_Analytics\train_LZdllcl.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
df_char=df.select_dtypes(include='object')

# %%
df_num=df.select_dtypes(include=[np.number])

# %%
df_num.corr()
# Out:
#                       employee_id  no_of_trainings       age  \
# employee_id              1.000000        -0.005121  0.000437
# no_of_trainings         -0.005121         1.000000 -0.081278
# age                      0.000437        -0.081278  1.000000
# previous_year_rating     0.004533        -0.063126  0.006008
# length_of_service        0.001274        -0.057275  0.657111
# KPIs_met >80%           -0.002501        -0.045576 -0.025592
# awards_won?              0.008420        -0.007628 -0.008169
# avg_training_score      -0.000586         0.042517 -0.048380
# is_promoted              0.001206        -0.024896 -0.017166
#
#                       previous_year_rating  length_of_service  KPIs_met >80%  \
# employee_id                       0.004533           0.001274      -0.002501
# no_of_trainings                  -0.063126          -0.057275      -0.045576
# age                               0.006008           0.657111      -0.025592
# ...

# %%
# pd.pivot_table(df,values='Admission_Deposit' ,index='Severity of Illness',columns='Type of Admission' ,aggfunc=[np.sum,np.mean,np.median,np.ptp,np.count])
