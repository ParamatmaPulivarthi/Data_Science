# %%
# Function/ user defined function

# %%
# syntax:
def function_name(parameters,..,par_n):
    <statements>
    <logic>
    return var
    return (var,var,var_n)

# %%
#scenario : create a function to add two number a and b

# %%
def addition():
    a=10
    b=20
    c=a+b
    return c

# %%
addition()
# Out:
# 30

# %%
def multiplication(a,b):
    
    
    c=a*b
    return c

# %%
multiplication(10,20)
# Out:
# 200

# %%
#scenario- share market :Returns for your investment amount is 20%. if no.of shares are more than 5 provide 5% extra percentage.

# %%
def share_market(invest_amount,share):
    if share>5 :
        retun=invest_amount*.25
    else :
        retun=invest_amount*.20
    return retun

# %%
share_market(100000,8)
# Out:
# 25000.0

# %%
share_market(100000,4)
# Out:
# 20000.0

# %%
#scenario- IPL-zoomato: Make predicted score & get offer. Team made <150 then 10% off on order. 
# score 150-200 then 20% ,
# score >200 then 50%

# %% [markdown]
# # Pandas

# %%
#Data Read/Import
#read_csv,read_excel,read_table
#sep,header,sheet_name

# %%
import pandas as  pd

# %%
dictt={"IPL_Teams":["KKR","MI","CSK","RCB","KXIIP","RR","SRH","DC"],"first_score": [10,20,40,50,60,70,80]}

# %%
dictt
# Out:
# {'IPL_Teams': ['KKR', 'MI', 'CSK', 'RCB', 'KXIIP', 'RR', 'SRH', 'DC'],
#  'first_score': [10, 20, 40, 50, 60, 70, 80]}

# %%
df=pd.DataFrame(dictt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d546cbc904d2> in <module>
# ----> 1 df=pd.DataFrame(dictt)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
# syntax?
pd.read_csv(path,sep='',header=None/'infer')

# %%
df=pd.read_csv(r"C:\Users\ppulivarthi\AV_Hackthons\Janatahack Healthcare Analytics II\train.csv")

# %%
# df=pd.read_csv(r"C:\Users\ppulivarthi\AV_Hackthons\Janatahack Healthcare Analytics II\train.csv",header=None)
# Out:
# C:\Users\ppulivarthi\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (0,1,3,5,9,10,11,14,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# syntax
pd.read_excel(path,sheet_name='',header=)

# %%
df_new=pd.read_excel(r"C:\Users\ppulivarthi\AV_Hackthons\Janatahack Healthcare Analytics II\train_dict_check_mine - Copy.xlsx")

# %%
df_new.head()
# Out:
#                  Column                           Description  \
# 0               case_id        Case_ID registered in Hospital
# 1         Hospital_code          Unique code for the Hospital
# 2    Hospital_type_code  Unique code for the type of Hospital
# 3    City_Code_Hospital             City Code of the Hospital
# 4  Hospital_region_code           Region Code of the Hospital
#
#   Missing values columns To select as features
# 0                     No                   NaN
# 1                     No                   Yes
# 2                     No                   NaN
# 3                     No                   Yes
# 4                     No                    no

# %%
df_new=pd.read_excel(r"C:\Users\ppulivarthi\AV_Hackthons\Janatahack Healthcare Analytics II\train_dict_check_mine - Copy.xlsx",sheet_name="Sheet2")

# %%
df_new.head()
# Out:
#    id name
# 0   1    a
# 1   2    b
# 2   3    c
# 3   4    d
# 4   5    e

# %%
df_new=pd.read_excel(r"C:\Users\ppulivarthi\AV_Hackthons\Janatahack Healthcare Analytics II\train_dict_check_mine - Copy.xlsx",sheet_name="Sheet2",header=None)

# %%
df_new
# Out:
#     0     1
# 0  id  name
# 1   1     a
# 2   2     b
# 3   3     c
# 4   4     d
# 5   5     e

# %%
df_tab=pd.read_csv(r"C:\Users\ppulivarthi\AV_Hackthons\Janatahack Healthcare Analytics II\sample_tab.txt",sep='\t')

# %%
df_tab.head()
# Out:
#     name  age  marks
# 0   Ravi   10     20
# 1  vinay   12     30
# 2  Ashok   13    340

# %%
read_table/

# %%
df.head()
# Out:
#         0              1                   2                   3   \
# 0  case_id  Hospital_code  Hospital_type_code  City_Code_Hospital
# 1        1              8                   c                   3
# 2        2              2                   c                   5
# 3        3             10                   e                   1
# 4        4             26                   b                   2
#
#                      4                                  5             6   \
# 0  Hospital_region_code  Available Extra Rooms in Hospital    Department
# 1                     Z                                  3  radiotherapy
# 2                     Z                                  2  radiotherapy
# 3                     X                                  2    anesthesia
# 4                     Y                                  2  radiotherapy
#
#           7                   8          9          10                 11  \
# 0  Ward_Type  Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient
# 1          R                   F        2.0      31397                7.0
# 2          S                   F        2.0      31397                7.0
# 3          S                   E        2.0      31397                7.0
# 4          R                   D        2.0      31397                7.0
#
#                   12                   13                     14     15  \
# 0  Type of Admission  Severity of Illness  Visitors with Patient    Age
# 1          Emergency              Extreme                      2  51-60
# 2             Trauma              Extreme                      2  51-60
# 3             Trauma              Extreme                      2  51-60
# 4             Trauma              Extreme                      2  51-60
#
#                   16     17
# 0  Admission_Deposit   Stay
# 1             4911.0   0-10
# 2             5954.0  41-50
# 3             4745.0  31-40
# 4             7272.0  41-50

# %%
df.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# 11    object
# 12    object
# 13    object
# 14    object
# 15    object
# 16    object
# 17    object
# dtype: object

# %%
df.shape
# Out:
# (318438, 18)

# %%
row=df.shape[0]
# Out:
# 318438

# %%
col=df.shape[1]

# %%
col
# Out:
# 18

# %%
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay
# 0             4911.0   0-10
# 1             5954.0  41-50
# 2             4745.0  31-40
# 3             7272.0  41-50
# 4             5558.0  41-50

# %%
df.head(10)
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
# 5        6             23                  a                   6
# 6        7             32                  f                   9
# 7        8             23                  a                   6
# 8        9              1                  d                  10
# 9       10             10                  e                   1
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
# 5                    X                                  2    anesthesia
# 6                    Y                                  1  radiotherapy
# 7                    X                                  4  radiotherapy
# 8                    Y                                  2    gynecology
# 9                    X                                  2    gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
# 5         S                  F        2.0      31397                7.0
# 6         S                  B        3.0      31397                7.0
# 7         Q                  F        3.0      31397                7.0
# 8         R                  B        4.0      31397                7.0
# 9         S                  E        3.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
# 5            Trauma             Extreme                      2  51-60
# 6         Emergency             Extreme                      2  51-60
# 7            Trauma             Extreme                      2  51-60
# 8            Trauma             Extreme                      2  51-60
# 9            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay
# 0             4911.0   0-10
# 1             5954.0  41-50
# 2             4745.0  31-40
# 3             7272.0  41-50
# 4             5558.0  41-50
# 5             4449.0  11-20
# 6             6167.0   0-10
# 7             5571.0  41-50
# 8             7223.0  51-60
# 9             6056.0  31-40

# %%
df.tail()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 318433                    X                                  3  radiotherapy
# 318434                    X                                  2    anesthesia
# 318435                    X                                  3    gynecology
# 318436                    Y                                  3    anesthesia
# 318437                    Y                                  5    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 318433         Q                  F        4.0      86499               23.0
# 318434         Q                  E        4.0        325                8.0
# 318435         R                  F        4.0     125235               10.0
# 318436         Q                  D        3.0      91081                8.0
# 318437         Q                  C        2.0      21641                8.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 318433         Emergency            Moderate                      3  41-50
# 318434            Urgent            Moderate                      4  81-90
# 318435         Emergency               Minor                      3  71-80
# 318436            Trauma               Minor                      5  11-20
# 318437         Emergency               Minor                      2  11-20
#
#         Admission_Deposit   Stay
# 318433             4144.0  11-20
# 318434             6699.0  31-40
# 318435             4235.0  11-20
# 318436             3761.0  11-20
# 318437             4752.0   0-10

# %%
df.tail(n=8)
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 318430   318431              6                  a                   6
# 318431   318432             23                  a                   6
# 318432   318433             26                  b                   2
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 318430                    X                                  3    anesthesia
# 318431                    X                                  3    anesthesia
# 318432                    Y                                  2    anesthesia
# 318433                    X                                  3  radiotherapy
# 318434                    X                                  2    anesthesia
# 318435                    X                                  3    gynecology
# 318436                    Y                                  3    anesthesia
# 318437                    Y                                  5    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 318430         Q                  F        4.0     109796                8.0
# 318431         Q                  F        4.0     120672                2.0
# 318432         R                  D        3.0      36018                6.0
# 318433         Q                  F        4.0      86499               23.0
# 318434         Q                  E        4.0        325                8.0
# 318435         R                  F        4.0     125235               10.0
# 318436         Q                  D        3.0      91081                8.0
# 318437         Q                  C        2.0      21641                8.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 318430            Trauma            Moderate                      2  41-50
# 318431            Urgent             Extreme                      2  71-80
# 318432         Emergency               Minor                      3  11-20
# 318433         Emergency            Moderate                      3  41-50
# 318434            Urgent            Moderate                      4  81-90
# 318435         Emergency               Minor                      3  71-80
# 318436            Trauma               Minor                      5  11-20
# 318437         Emergency               Minor                      2  11-20
#
#         Admission_Deposit   Stay
# 318430             5065.0  21-30
# 318431             4508.0  11-20
# 318432             8308.0  21-30
# 318433             4144.0  11-20
# 318434             6699.0  31-40
# 318435             4235.0  11-20
# 318436             3761.0  11-20
# 318437             4752.0   0-10

# %%
df.tail(8)
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 318430   318431              6                  a                   6
# 318431   318432             23                  a                   6
# 318432   318433             26                  b                   2
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 318430                    X                                  3    anesthesia
# 318431                    X                                  3    anesthesia
# 318432                    Y                                  2    anesthesia
# 318433                    X                                  3  radiotherapy
# 318434                    X                                  2    anesthesia
# 318435                    X                                  3    gynecology
# 318436                    Y                                  3    anesthesia
# 318437                    Y                                  5    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 318430         Q                  F        4.0     109796                8.0
# 318431         Q                  F        4.0     120672                2.0
# 318432         R                  D        3.0      36018                6.0
# 318433         Q                  F        4.0      86499               23.0
# 318434         Q                  E        4.0        325                8.0
# 318435         R                  F        4.0     125235               10.0
# 318436         Q                  D        3.0      91081                8.0
# 318437         Q                  C        2.0      21641                8.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 318430            Trauma            Moderate                      2  41-50
# 318431            Urgent             Extreme                      2  71-80
# 318432         Emergency               Minor                      3  11-20
# 318433         Emergency            Moderate                      3  41-50
# 318434            Urgent            Moderate                      4  81-90
# 318435         Emergency               Minor                      3  71-80
# 318436            Trauma               Minor                      5  11-20
# 318437         Emergency               Minor                      2  11-20
#
#         Admission_Deposit   Stay
# 318430             5065.0  21-30
# 318431             4508.0  11-20
# 318432             8308.0  21-30
# 318433             4144.0  11-20
# 318434             6699.0  31-40
# 318435             4235.0  11-20
# 318436             3761.0  11-20
# 318437             4752.0   0-10

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
lst=list(df.columns)

# %%
lst
# Out:
# ['case_id',
#  'Hospital_code',
#  'Hospital_type_code',
#  'City_Code_Hospital',
#  'Hospital_region_code',
#  'Available Extra Rooms in Hospital',
#  'Department',
#  'Ward_Type',
#  'Ward_Facility_Code',
#  'Bed Grade',
#  'patientid',
#  'City_Code_Patient',
#  'Type of Admission',
#  'Severity of Illness',
#  'Visitors with Patient',
#  'Age',
#  'Admission_Deposit',
#  'Stay']

# %%
for p in lst:
    print(p)
# Out:
# case_id
# Hospital_code
# Hospital_type_code
# City_Code_Hospital
# Hospital_region_code
# Available Extra Rooms in Hospital
# Department
# Ward_Type
# Ward_Facility_Code
# Bed Grade
# patientid
# City_Code_Patient
# Type of Admission
# Severity of Illness
# Visitors with Patient
# Age
# Admission_Deposit
# Stay

# %%
lst1=lst[2:]

# %%
lst1
# Out:
# ['Hospital_type_code',
#  'City_Code_Hospital',
#  'Hospital_region_code',
#  'Available Extra Rooms in Hospital',
#  'Department',
#  'Ward_Type',
#  'Ward_Facility_Code',
#  'Bed Grade',
#  'patientid',
#  'City_Code_Patient',
#  'Type of Admission',
#  'Severity of Illness',
#  'Visitors with Patient',
#  'Age',
#  'Admission_Deposit',
#  'Stay']

# %%
df.dtypes
# Out:
# case_id                                int64
# Hospital_code                          int64
# Hospital_type_code                    object
# City_Code_Hospital                     int64
# Hospital_region_code                  object
# Available Extra Rooms in Hospital      int64
# Department                            object
# Ward_Type                             object
# Ward_Facility_Code                    object
# Bed Grade                            float64
# patientid                              int64
# City_Code_Patient                    float64
# Type of Admission                     object
# Severity of Illness                   object
# Visitors with Patient                  int64
# Age                                   object
# Admission_Deposit                    float64
# Stay                                  object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=318438, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital_code                      318438 non-null  int64
#  2   Hospital_type_code                 318438 non-null  object
#  3   City_Code_Hospital                 318438 non-null  int64
#  4   Hospital_region_code               318438 non-null  object
#  5   Available Extra Rooms in Hospital  318438 non-null  int64
#  6   Department                         318438 non-null  object
#  7   Ward_Type                          318438 non-null  object
#  8   Ward_Facility_Code                 318438 non-null  object
#  9   Bed Grade                          318325 non-null  float64
#  10  patientid                          318438 non-null  int64
#  11  City_Code_Patient                  313906 non-null  float64
#  12  Type of Admission                  318438 non-null  object
#  13  Severity of Illness                318438 non-null  object
#  14  Visitors with Patient              318438 non-null  int64
#  15  Age                                318438 non-null  object
#  16  Admission_Deposit                  318438 non-null  float64
#  17  Stay                               318438 non-null  object
# dtypes: float64(3), int64(6), object(9)
# memory usage: 43.7+ MB

# %%
# Basic checks
# index,shape,head,tail,colums,dtypes,info

# %%
# filters/Condition
# ==,!=,>,>=,<,<=
# &(and), | (or), isin, ~isin(not in)
#Scenario: Filter only Department is anesthesia
#Scenario: Filter Department except anesthesia
#Scenario: Filter Visitors with Patient are greater than 2
#Scenario: Filter Admission_Deposit is greater than or equal to 5000
#Scenario: Filter City_Code_Hospital are less than 4
#Scenario: Filter Available Extra Rooms in Hospital is less than or equal to 3
#scenario: filter the data for patientid 31397 and Visitors with Patient 2
#scenario: filter the data for Severity of Illness is Extreme or Type of Admission is Emergency
#scenario: filter the data for Department in 'radiotherapy', 'anesthesia' & 'gynecology'
#scenario: filter the data for Ward_Type not in 'S', 'Q' & 'P'

# %%
#Scenario: Filter only Department is anesthesia

# %%
df=pd.read_csv(r"C:\Users\ppulivarthi\AV_Hackthons\Janatahack Healthcare Analytics II\train.csv")

# %%
df.Department.unique()
# Out:
# array(['radiotherapy', 'anesthesia', 'gynecology', 'TB & Chest disease',
#        'surgery'], dtype=object)

# %%
# syntax:df[filter]
df_dep_fil=df[df['Department']=='anesthesia']

# %%
df_dep_fil.Department.unique()
# Out:
# array(['anesthesia'], dtype=object)

# %%
#Scenario: Filter Department except anesthesia

# %%
df_dep_fil_ex=df[df['Department']!='anesthesia']

# %%
df_dep_fil_ex=df[df['Department']~='anesthesia']
# Out:
#   File "<ipython-input-79-fdd53a96f0db>", line 1
#     df_dep_fil_ex=df[df['Department']~='anesthesia']
#                                      ^
# SyntaxError: invalid syntax

# %%
df_dep_fil_ex=df[df['Department']^='anesthesia']
# Out:
#   File "<ipython-input-80-61578975119c>", line 1
#     df_dep_fil_ex=df[df['Department']^='anesthesia']
#                                       ^
# SyntaxError: invalid syntax

# %%
df_dep_fil_ex.Department.unique()
# Out:
# array(['radiotherapy', 'gynecology', 'TB & Chest disease', 'surgery'],
#       dtype=object)

# %%
#Scenario: Filter Visitors with Patient are greater than 2

# %%
dfgr_2=df[df['Visitors with Patient']>2]

# %%
dfgr_2['Visitors with Patient'].unique()
# Out:
# array([ 4,  3,  8,  6,  7, 13,  5, 10, 15, 11, 12,  9, 24, 16, 14, 20, 19,
#        18, 17, 23, 21, 32, 30, 22, 25], dtype=int64)

# %%
#scenario: filter the data for patientid 31397 and Visitors with Patient 2

# %%
df_fil_and=df[(df['patientid']==31397) &    (df['Visitors with Patient']==2)]

# %%
df_fil_and.shape
# Out:
# (14, 18)

# %%
df_fil_and['patientid'].unique()
# Out:
# array([31397], dtype=int64)

# %%
df_fil_and['Visitors with Patient'].unique()
# Out:
# array([2], dtype=int64)

# %%
#scenario: filter the data for Severity of Illness is Extreme or Type of Admission is Emergency
df_fil_or=df[(df['Severity of Illness']=='Extreme')| (df['Type of Admission']=='Emergency')]

# %%
df_fil_or['Severity of Illness'].unique()
# Out:
# array(['Extreme', 'Moderate', 'Minor'], dtype=object)

# %%
df_fil_or['Type of Admission'].unique()
# Out:
# array(['Emergency', 'Trauma', 'Urgent'], dtype=object)

# %%
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay
# 0             4911.0   0-10
# 1             5954.0  41-50
# 2             4745.0  31-40
# 3             7272.0  41-50
# 4             5558.0  41-50

# %%
#scenario: filter the data for Department in 'radiotherapy', 'anesthesia' & 'gynecology'

# %%
lst=['radiotherapy', 'anesthesia', 'gynecology']

# %%
df_lst=df[df['Department'].isin(lst)]

# %%
df_lst=df[df['Department'].isin(['radiotherapy', 'anesthesia', 'gynecology'])]

# %%
df_lst.Department.unique()
# Out:
# array(['radiotherapy', 'anesthesia', 'gynecology'], dtype=object)

# %%
df_lst_nt=df[~df['Department'].isin(['radiotherapy', 'anesthesia', 'gynecology'])]

# %%
df_lst_nt.Department.unique()
# Out:
# array(['TB & Chest disease', 'surgery'], dtype=object)

# %%
# unique()
df.Hospital_code
df['case_id']

# %%
df.Hospital_code.unique()
# Out:
# array([ 8,  2, 10, 26, 23, 32,  1, 22, 16,  9,  6, 29, 12,  3, 21, 28, 27,
#        19,  5, 14, 13, 31, 24, 17, 25, 15, 11, 30, 18,  4,  7, 20],
#       dtype=int64)

# %%
df.Department.unique()
# Out:
# array(['radiotherapy', 'anesthesia', 'gynecology', 'TB & Chest disease',
#        'surgery'], dtype=object)

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
df_new=df[['Hospital_code', 'Hospital_type_code']]

# %%
lst=['Hospital_code', 'Hospital_type_code']

# %%
df_new=df[lst]

# %%
df_new
# Out:
#         Hospital_code Hospital_type_code
# 0                   8                  c
# 1                   2                  c
# 2                  10                  e
# 3                  26                  b
# 4                  26                  b
# ...               ...                ...
# 318433              6                  a
# 318434             24                  a
# 318435              7                  a
# 318436             11                  b
# 318437             19                  a
#
# [318438 rows x 2 columns]

# %%
df_new[['Hospital_type_code']][1:5]
# Out:
#   Hospital_type_code
# 1                  c
# 2                  e
# 3                  b
# 4                  b

# %%
# df_new[['Hospital_type_code']][-5]

# %%
df[1:2][1:5]
# Out:
# Empty DataFrame
# Columns: [case_id, Hospital_code, Hospital_type_code, City_Code_Hospital, Hospital_region_code, Available Extra Rooms in Hospital, Department, Ward_Type, Ward_Facility_Code, Bed Grade, patientid, City_Code_Patient, Type of Admission, Severity of Illness, Visitors with Patient, Age, Admission_Deposit, Stay]
# Index: []

# %%
df_new.head()
# Out:
#    Hospital_code Hospital_type_code
# 0              8                  c
# 1              2                  c
# 2             10                  e
# 3             26                  b
# 4             26                  b

# %%
df[['City_Code_Hospital']]
# Out:
#         City_Code_Hospital
# 0                        3
# 1                        5
# 2                        1
# 3                        2
# 4                        2
# ...                    ...
# 318433                   6
# 318434                   1
# 318435                   4
# 318436                   2
# 318437                   7
#
# [318438 rows x 1 columns]

# %%
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay
# 0             4911.0   0-10
# 1             5954.0  41-50
# 2             4745.0  31-40
# 3             7272.0  41-50
# 4             5558.0  41-50

# %%
# concatination/appending
# axis,ignore_index

# %%
df=pd.read_csv(r"C:\Users\ppulivarthi\AV_Hackthons\Janatahack Healthcare Analytics II\train.csv")

# %%
# df.info()
df.head()

df1=df[:10]

# %%
df2=df[10:20]

# %%
df1.shape
# Out:
# (10, 18)

# %%
df2.shape
# Out:
# (10, 18)

# %%
# df1.head()
df2.head()
# Out:
#     case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 10       11             22                  g                   9
# 11       12             26                  b                   2
# 12       13             16                  c                   3
# 13       14              9                  d                   5
# 14       15              6                  a                   6
#
#    Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 10                    Y                                  2  radiotherapy
# 11                    Y                                  4  radiotherapy
# 12                    Z                                  2  radiotherapy
# 13                    Z                                  3  radiotherapy
# 14                    X                                  4    gynecology
#
#    Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 10         S                  B        2.0      31397                7.0
# 11         R                  D        1.0      31397                7.0
# 12         R                  A        3.0      31397                7.0
# 13         S                  F        3.0      31397                7.0
# 14         Q                  F        3.0      63418                8.0
#
#    Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 10            Urgent             Extreme                      2  51-60
# 11            Urgent             Extreme                      2  51-60
# 12         Emergency             Extreme                      2  51-60
# 13            Urgent             Extreme                      2  51-60
# 14         Emergency             Extreme                      2  71-80
#
#     Admission_Deposit   Stay
# 10             5797.0  21-30
# 11             5993.0  11-20
# 12             5141.0   0-10
# 13             8477.0  21-30
# 14             2685.0   0-10

# %%
import pandas as pd

# %%
concat(argu,aug1,aur3)

# %%
df_new=pd.concat([df1,df2,],axis=0)

# %%
df_new.shape
# Out:
# (20, 18)

# %%
df_new
# Out:
#     case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0         1              8                  c                   3
# 1         2              2                  c                   5
# 2         3             10                  e                   1
# 3         4             26                  b                   2
# 4         5             26                  b                   2
# 5         6             23                  a                   6
# 6         7             32                  f                   9
# 7         8             23                  a                   6
# 8         9              1                  d                  10
# 9        10             10                  e                   1
# 10       11             22                  g                   9
# 11       12             26                  b                   2
# 12       13             16                  c                   3
# 13       14              9                  d                   5
# 14       15              6                  a                   6
# 15       16              6                  a                   6
# 16       17             23                  a                   6
# 17       18             29                  a                   4
# 18       19             32                  f                   9
# 19       20             12                  a                   9
#
#    Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                     Z                                  3  radiotherapy
# 1                     Z                                  2  radiotherapy
# 2                     X                                  2    anesthesia
# 3                     Y                                  2  radiotherapy
# 4                     Y                                  2  radiotherapy
# 5                     X                                  2    anesthesia
# 6                     Y                                  1  radiotherapy
# 7                     X                                  4  radiotherapy
# 8                     Y                                  2    gynecology
# 9                     X                                  2    gynecology
# 10                    Y                                  2  radiotherapy
# 11                    Y                                  4  radiotherapy
# 12                    Z                                  2  radiotherapy
# 13                    Z                                  3  radiotherapy
# 14                    X                                  4    gynecology
# 15                    X                                  3    gynecology
# 16                    X                                  4  radiotherapy
# 17                    X                                  4    anesthesia
# 18                    Y                                  4  radiotherapy
# 19                    Y                                  4  radiotherapy
#
#    Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0          R                  F        2.0      31397                7.0
# 1          S                  F        2.0      31397                7.0
# 2          S                  E        2.0      31397                7.0
# 3          R                  D        2.0      31397                7.0
# 4          S                  D        2.0      31397                7.0
# 5          S                  F        2.0      31397                7.0
# 6          S                  B        3.0      31397                7.0
# 7          Q                  F        3.0      31397                7.0
# 8          R                  B        4.0      31397                7.0
# 9          S                  E        3.0      31397                7.0
# 10         S                  B        2.0      31397                7.0
# 11         R                  D        1.0      31397                7.0
# 12         R                  A        3.0      31397                7.0
# 13         S                  F        3.0      31397                7.0
# 14         Q                  F        3.0      63418                8.0
# 15         Q                  F        3.0      63418                8.0
# 16         Q                  F        3.0      63418                8.0
# 17         S                  F        3.0      63418                8.0
# 18         S                  B        2.0      63418                8.0
# 19         Q                  B        2.0      63418                8.0
#
#    Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0          Emergency             Extreme                      2  51-60
# 1             Trauma             Extreme                      2  51-60
# 2             Trauma             Extreme                      2  51-60
# 3             Trauma             Extreme                      2  51-60
# 4             Trauma             Extreme                      2  51-60
# 5             Trauma             Extreme                      2  51-60
# 6          Emergency             Extreme                      2  51-60
# 7             Trauma             Extreme                      2  51-60
# 8             Trauma             Extreme                      2  51-60
# 9             Trauma             Extreme                      2  51-60
# 10            Urgent             Extreme                      2  51-60
# 11            Urgent             Extreme                      2  51-60
# 12         Emergency             Extreme                      2  51-60
# 13            Urgent             Extreme                      2  51-60
# 14         Emergency             Extreme                      2  71-80
# 15         Emergency             Extreme                      2  71-80
# 16            Urgent             Extreme                      4  71-80
# 17         Emergency             Extreme                      2  71-80
# 18            Trauma             Extreme                      2  71-80
# 19            Trauma             Extreme                      2  71-80
#
#     Admission_Deposit   Stay
# 0              4911.0   0-10
# 1              5954.0  41-50
# 2              4745.0  31-40
# 3              7272.0  41-50
# 4              5558.0  41-50
# 5              4449.0  11-20
# 6              6167.0   0-10
# 7              5571.0  41-50
# 8              7223.0  51-60
# 9              6056.0  31-40
# 10             5797.0  21-30
# 11             5993.0  11-20
# 12             5141.0   0-10
# 13             8477.0  21-30
# 14             2685.0   0-10
# 15             9398.0   0-10
# 16             2933.0   0-10
# 17             5342.0  11-20
# 18             7442.0  21-30
# 19             5155.0  31-40

# %%
df_new_reverse=pd.concat([df2,df1],axis=0)

# %%
df_new_reverse
# Out:
#     case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 10       11             22                  g                   9
# 11       12             26                  b                   2
# 12       13             16                  c                   3
# 13       14              9                  d                   5
# 14       15              6                  a                   6
# 15       16              6                  a                   6
# 16       17             23                  a                   6
# 17       18             29                  a                   4
# 18       19             32                  f                   9
# 19       20             12                  a                   9
# 0         1              8                  c                   3
# 1         2              2                  c                   5
# 2         3             10                  e                   1
# 3         4             26                  b                   2
# 4         5             26                  b                   2
# 5         6             23                  a                   6
# 6         7             32                  f                   9
# 7         8             23                  a                   6
# 8         9              1                  d                  10
# 9        10             10                  e                   1
#
#    Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 10                    Y                                  2  radiotherapy
# 11                    Y                                  4  radiotherapy
# 12                    Z                                  2  radiotherapy
# 13                    Z                                  3  radiotherapy
# 14                    X                                  4    gynecology
# 15                    X                                  3    gynecology
# 16                    X                                  4  radiotherapy
# 17                    X                                  4    anesthesia
# 18                    Y                                  4  radiotherapy
# 19                    Y                                  4  radiotherapy
# 0                     Z                                  3  radiotherapy
# 1                     Z                                  2  radiotherapy
# 2                     X                                  2    anesthesia
# 3                     Y                                  2  radiotherapy
# 4                     Y                                  2  radiotherapy
# 5                     X                                  2    anesthesia
# 6                     Y                                  1  radiotherapy
# 7                     X                                  4  radiotherapy
# 8                     Y                                  2    gynecology
# 9                     X                                  2    gynecology
#
#    Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 10         S                  B        2.0      31397                7.0
# 11         R                  D        1.0      31397                7.0
# 12         R                  A        3.0      31397                7.0
# 13         S                  F        3.0      31397                7.0
# 14         Q                  F        3.0      63418                8.0
# 15         Q                  F        3.0      63418                8.0
# 16         Q                  F        3.0      63418                8.0
# 17         S                  F        3.0      63418                8.0
# 18         S                  B        2.0      63418                8.0
# 19         Q                  B        2.0      63418                8.0
# 0          R                  F        2.0      31397                7.0
# 1          S                  F        2.0      31397                7.0
# 2          S                  E        2.0      31397                7.0
# 3          R                  D        2.0      31397                7.0
# 4          S                  D        2.0      31397                7.0
# 5          S                  F        2.0      31397                7.0
# 6          S                  B        3.0      31397                7.0
# 7          Q                  F        3.0      31397                7.0
# 8          R                  B        4.0      31397                7.0
# 9          S                  E        3.0      31397                7.0
#
#    Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 10            Urgent             Extreme                      2  51-60
# 11            Urgent             Extreme                      2  51-60
# 12         Emergency             Extreme                      2  51-60
# 13            Urgent             Extreme                      2  51-60
# 14         Emergency             Extreme                      2  71-80
# 15         Emergency             Extreme                      2  71-80
# 16            Urgent             Extreme                      4  71-80
# 17         Emergency             Extreme                      2  71-80
# 18            Trauma             Extreme                      2  71-80
# 19            Trauma             Extreme                      2  71-80
# 0          Emergency             Extreme                      2  51-60
# 1             Trauma             Extreme                      2  51-60
# 2             Trauma             Extreme                      2  51-60
# 3             Trauma             Extreme                      2  51-60
# 4             Trauma             Extreme                      2  51-60
# 5             Trauma             Extreme                      2  51-60
# 6          Emergency             Extreme                      2  51-60
# 7             Trauma             Extreme                      2  51-60
# 8             Trauma             Extreme                      2  51-60
# 9             Trauma             Extreme                      2  51-60
#
#     Admission_Deposit   Stay
# 10             5797.0  21-30
# 11             5993.0  11-20
# 12             5141.0   0-10
# 13             8477.0  21-30
# 14             2685.0   0-10
# 15             9398.0   0-10
# 16             2933.0   0-10
# 17             5342.0  11-20
# 18             7442.0  21-30
# 19             5155.0  31-40
# 0              4911.0   0-10
# 1              5954.0  41-50
# 2              4745.0  31-40
# 3              7272.0  41-50
# 4              5558.0  41-50
# 5              4449.0  11-20
# 6              6167.0   0-10
# 7              5571.0  41-50
# 8              7223.0  51-60
# 9              6056.0  31-40

# %%
df_new_reverse_ign=pd.concat([df2,df1],axis=0,ignore_index=True)

# %%
df_new_reverse_ign
# Out:
#     case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        11             22                  g                   9
# 1        12             26                  b                   2
# 2        13             16                  c                   3
# 3        14              9                  d                   5
# 4        15              6                  a                   6
# 5        16              6                  a                   6
# 6        17             23                  a                   6
# 7        18             29                  a                   4
# 8        19             32                  f                   9
# 9        20             12                  a                   9
# 10        1              8                  c                   3
# 11        2              2                  c                   5
# 12        3             10                  e                   1
# 13        4             26                  b                   2
# 14        5             26                  b                   2
# 15        6             23                  a                   6
# 16        7             32                  f                   9
# 17        8             23                  a                   6
# 18        9              1                  d                  10
# 19       10             10                  e                   1
#
#    Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                     Y                                  2  radiotherapy
# 1                     Y                                  4  radiotherapy
# 2                     Z                                  2  radiotherapy
# 3                     Z                                  3  radiotherapy
# 4                     X                                  4    gynecology
# 5                     X                                  3    gynecology
# 6                     X                                  4  radiotherapy
# 7                     X                                  4    anesthesia
# 8                     Y                                  4  radiotherapy
# 9                     Y                                  4  radiotherapy
# 10                    Z                                  3  radiotherapy
# 11                    Z                                  2  radiotherapy
# 12                    X                                  2    anesthesia
# 13                    Y                                  2  radiotherapy
# 14                    Y                                  2  radiotherapy
# 15                    X                                  2    anesthesia
# 16                    Y                                  1  radiotherapy
# 17                    X                                  4  radiotherapy
# 18                    Y                                  2    gynecology
# 19                    X                                  2    gynecology
#
#    Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0          S                  B        2.0      31397                7.0
# 1          R                  D        1.0      31397                7.0
# 2          R                  A        3.0      31397                7.0
# 3          S                  F        3.0      31397                7.0
# 4          Q                  F        3.0      63418                8.0
# 5          Q                  F        3.0      63418                8.0
# 6          Q                  F        3.0      63418                8.0
# 7          S                  F        3.0      63418                8.0
# 8          S                  B        2.0      63418                8.0
# 9          Q                  B        2.0      63418                8.0
# 10         R                  F        2.0      31397                7.0
# 11         S                  F        2.0      31397                7.0
# 12         S                  E        2.0      31397                7.0
# 13         R                  D        2.0      31397                7.0
# 14         S                  D        2.0      31397                7.0
# 15         S                  F        2.0      31397                7.0
# 16         S                  B        3.0      31397                7.0
# 17         Q                  F        3.0      31397                7.0
# 18         R                  B        4.0      31397                7.0
# 19         S                  E        3.0      31397                7.0
#
#    Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0             Urgent             Extreme                      2  51-60
# 1             Urgent             Extreme                      2  51-60
# 2          Emergency             Extreme                      2  51-60
# 3             Urgent             Extreme                      2  51-60
# 4          Emergency             Extreme                      2  71-80
# 5          Emergency             Extreme                      2  71-80
# 6             Urgent             Extreme                      4  71-80
# 7          Emergency             Extreme                      2  71-80
# 8             Trauma             Extreme                      2  71-80
# 9             Trauma             Extreme                      2  71-80
# 10         Emergency             Extreme                      2  51-60
# 11            Trauma             Extreme                      2  51-60
# 12            Trauma             Extreme                      2  51-60
# 13            Trauma             Extreme                      2  51-60
# 14            Trauma             Extreme                      2  51-60
# 15            Trauma             Extreme                      2  51-60
# 16         Emergency             Extreme                      2  51-60
# 17            Trauma             Extreme                      2  51-60
# 18            Trauma             Extreme                      2  51-60
# 19            Trauma             Extreme                      2  51-60
#
#     Admission_Deposit   Stay
# 0              5797.0  21-30
# 1              5993.0  11-20
# 2              5141.0   0-10
# 3              8477.0  21-30
# 4              2685.0   0-10
# 5              9398.0   0-10
# 6              2933.0   0-10
# 7              5342.0  11-20
# 8              7442.0  21-30
# 9              5155.0  31-40
# 10             4911.0   0-10
# 11             5954.0  41-50
# 12             4745.0  31-40
# 13             7272.0  41-50
# 14             5558.0  41-50
# 15             4449.0  11-20
# 16             6167.0   0-10
# 17             5571.0  41-50
# 18             7223.0  51-60
# 19             6056.0  31-40

# %%
DataFrame(dict)

# %%
dictt={"IPL Team" : ['RCB','RCB','RCB'],"Match" :['Match-1','Match-2','Match-3'],"Score":[163,109,201]}

# %%
dictt={"IPL Team" : ['RCB',' ',' '],"Match" :['Match-1','Match-2','Match-3'],"Score":[163,109,201]}

# %%
# dictt
# Out:
# {'IPL Team': ['RCB', 'RCB', 'RCB'],
#  'Match': ['Match-1', 'Match-2', 'Match-3'],
#  'Score': [163, 109, 201]}

# %%
df_dict=pd.DataFrame(dictt)

# %%
df_dict_new=pd.DataFrame(dictt)

# %%
df_dict_new
# Out:
#   IPL Team    Match  Score
# 0      RCB  Match-1    163
# 1           Match-2    109
# 2           Match-3    201

# %%
df_dict
# Out:
#   IPL Team    Match  Score
# 0      RCB  Match-1    163
# 1      RCB  Match-2    109
# 2      RCB  Match-3    201

# %%
df_dict_app=pd.concat([df_dict,df_dict_new],axis=0)

# %%
df_dict_app
# Out:
#   IPL Team    Match  Score
# 0      RCB  Match-1    163
# 1      RCB  Match-2    109
# 2      RCB  Match-3    201
# 0      RCB  Match-1    163
# 1           Match-2    109
# 2           Match-3    201

# %%
df_dict_app['IPL Team'][0]
# Out:
# 0    RCB
# 0    RCB
# Name: IPL Team, dtype: object

# %%
df_dict_app=pd.concat([df_dict,df_dict_new],axis=0,ignore_index=True)

# %%
df_dict_app
# Out:
#   IPL Team    Match  Score
# 0      RCB  Match-1    163
# 1      RCB  Match-2    109
# 2      RCB  Match-3    201
# 3      RCB  Match-1    163
# 4           Match-2    109
# 5           Match-3    201

# %%
df_dict_app['IPL Team'][4]
# Out:
# ' '

# %%
df_dict_app_ax=pd.concat([df_dict,df_dict_new],axis=1,ignore_index=True)

# %%
df_dict_app_ax.shape
# Out:
# (3, 6)

# %%
df_dict_app_ax
# Out:
#      0        1    2    3        4    5
# 0  RCB  Match-1  163  RCB  Match-1  163
# 1  RCB  Match-2  109       Match-2  109
# 2  RCB  Match-3  201       Match-3  201

# %%
dict1={"IPL Team" : ['RCB','RCB'], "Match" : ['Match-1','Match-2'], 'SCORE' :[120,168]}

# %%
dict2={"IPL Team" : ['RCB','RCB'], "Match" : ['Match-1','Match-2'], 'MANOFMATCH' :["KOHLI","AB DE"]}

# %%
df_ipl1=pd.DataFrame(dict1)

# %%
df_ipl2=pd.DataFrame(dict2)

# %%
df_ipl1
# Out:
#   IPL Team    Match  SCORE
# 0      RCB  Match-1    120
# 1      RCB  Match-2    168

# %%
df_ipl2
# Out:
#   IPL Team    Match MANOFMATCH
# 0      RCB  Match-1      KOHLI
# 1      RCB  Match-2      AB DE

# %%
df_ipl3=pd.concat([df_ipl1,df_ipl2],axis=1)

# %%
df_ipl3
# Out:
#   IPL Team    Match  SCORE IPL Team    Match MANOFMATCH
# 0      RCB  Match-1    120      RCB  Match-1      KOHLI
# 1      RCB  Match-2    168      RCB  Match-2      AB DE

# %%
df_ipl3=pd.concat([df_ipl1,df_ipl2],axis=0)

# %%
df_ipl3
# Out:
#   IPL Team    Match  SCORE MANOFMATCH
# 0      RCB  Match-1  120.0        NaN
# 1      RCB  Match-2  168.0        NaN
# 0      RCB  Match-1    NaN      KOHLI
# 1      RCB  Match-2    NaN      AB DE

# %%
#join/merge
# df.merge(right,how=,on=)

# %%
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay
# 0             4911.0   0-10
# 1             5954.0  41-50
# 2             4745.0  31-40
# 3             7272.0  41-50
# 4             5558.0  41-50

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
df_cl_f1=df[['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital']]

# %%
df_cl_f2=df[['case_id','Ward_Type', 'Ward_Facility_Code', 'Bed Grade']]

# %%
df_cl_f1.shape
# Out:
# (318438, 4)

# %%
df_cl_f2.shape
# Out:
# (318438, 4)

# %%
df_merge1=df_cl_f1.merge(df,how='inner/left/right/outer',on=['']/''/)

# %%
#grouping/Summarizing

df_cl_f3=df[['case_id','Ward_Type', 'Ward_Facility_Code', 'Bed Grade']]

# %%
df_cl_f3=df_cl_f3[:1000]

# %%
df_cl_f3.shape
# Out:
# (1000, 4)

# %%
df_cl_f2.shape
# Out:
# (318438, 4)

# %%
df_inner_merge=df_cl_f2.merge(df_cl_f3,how='inner',on='case_id')

# %%
df_inner_merge.shape
# Out:
# (1000, 7)

# %%
df_inner_merge.columns
# Out:
# Index(['case_id', 'Ward_Type_x', 'Ward_Facility_Code_x', 'Bed Grade_x',
#        'Ward_Type_y', 'Ward_Facility_Code_y', 'Bed Grade_y'],
#       dtype='object')

# %%
df_inner_merge
# Out:
#      case_id Ward_Type_x Ward_Facility_Code_x  Bed Grade_x Ward_Type_y  \
# 0          1           R                    F          2.0           R
# 1          2           S                    F          2.0           S
# 2          3           S                    E          2.0           S
# 3          4           R                    D          2.0           R
# 4          5           S                    D          2.0           S
# ..       ...         ...                  ...          ...         ...
# 995      996           R                    F          4.0           R
# 996      997           Q                    F          4.0           Q
# 997      998           Q                    E          2.0           Q
# 998      999           R                    F          4.0           R
# 999     1000           Q                    F          3.0           Q
#
#     Ward_Facility_Code_y  Bed Grade_y
# 0                      F          2.0
# 1                      F          2.0
# 2                      E          2.0
# 3                      D          2.0
# 4                      D          2.0
# ..                   ...          ...
# 995                    F          4.0
# 996                    F          4.0
# 997                    E          2.0
# 998                    F          4.0
# 999                    F          3.0
#
# [1000 rows x 7 columns]

# %%
df_left_merge=df_cl_f2.merge(df_cl_f3,how='left',on='case_id')

# %%
df_left_merge.shape
# Out:
# (318438, 7)

# %%
df_left_merge.tail()
# Out:
#         case_id Ward_Type_x Ward_Facility_Code_x  Bed Grade_x Ward_Type_y  \
# 318433   318434           Q                    F          4.0         NaN
# 318434   318435           Q                    E          4.0         NaN
# 318435   318436           R                    F          4.0         NaN
# 318436   318437           Q                    D          3.0         NaN
# 318437   318438           Q                    C          2.0         NaN
#
#        Ward_Facility_Code_y  Bed Grade_y
# 318433                  NaN          NaN
# 318434                  NaN          NaN
# 318435                  NaN          NaN
# 318436                  NaN          NaN
# 318437                  NaN          NaN

# %%
df_right_merge=df_cl_f2.merge(df_cl_f3,how='right',on='case_id')

# %%
df_right_merge.shape
# Out:
# (1000, 7)

# %%
df_right_merge.tail()
# Out:
#      case_id Ward_Type_x Ward_Facility_Code_x  Bed Grade_x Ward_Type_y  \
# 995      996           R                    F          4.0           R
# 996      997           Q                    F          4.0           Q
# 997      998           Q                    E          2.0           Q
# 998      999           R                    F          4.0           R
# 999     1000           Q                    F          3.0           Q
#
#     Ward_Facility_Code_y  Bed Grade_y
# 995                    F          4.0
# 996                    F          4.0
# 997                    E          2.0
# 998                    F          4.0
# 999                    F          3.0

# %%
df_right_merge=df_cl_f2.merge(df_cl_f3,how='outer',on='case_id')

# %%
df_cl_f4_out=df_cl_f2[:2000]

# %%
df_cl_f5_out=df_cl_f2[1000:3000]

# %%
df_outer_merge=df_cl_f4_out.merge(df_cl_f5_out,how='outer',on='case_id')

# %%
df_outer_merge.shape
# Out:
# (3000, 7)

# %%
df_outer_merge.tail()
# Out:
#       case_id Ward_Type_x Ward_Facility_Code_x  Bed Grade_x Ward_Type_y  \
# 2995     2996         NaN                  NaN          NaN           R
# 2996     2997         NaN                  NaN          NaN           Q
# 2997     2998         NaN                  NaN          NaN           R
# 2998     2999         NaN                  NaN          NaN           R
# 2999     3000         NaN                  NaN          NaN           R
#
#      Ward_Facility_Code_y  Bed Grade_y
# 2995                    E          4.0
# 2996                    D          3.0
# 2997                    A          2.0
# 2998                    F          3.0
# 2999                    F          3.0
