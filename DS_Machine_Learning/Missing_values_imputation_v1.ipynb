# %% [markdown]
# # converting data to normal distribution & Outerlier analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Conversions

# %%
#series
#drop(axis=0/1,inplace=True)
#sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)
#drop_duplicates(subset=None/['var1','var2'], keep='first/last', inplace=False/True, ignore_index=False/True)
#reset_index(level=None, drop=False/True, inplace=False/true, col_level=0, col_fill='')
#conversions
# DataFrame(data=None/array/list/dict/series, index=None, columns=None, dtype=None, copy=False
# list to Dataframe vise-versa--df.val.tolist(),df.columns.tolist(),df.var.tolist()
#array to Dataframe vise-versa
# DataFrame.to_numpy(dtype=None, copy=False, na_value=<object object>)
# list to array vise-versa--

# %%
df=pd.read_csv(r"C:\Paramatma_Pulivarthi\Data_Science_course\recipeData.csv",encoding='latin-1')

# %%
# df.head()
#drop(axis=0/1,inplace=True)

# %%
#drop the observatios [2,5,8,9]

# %%
df_filter=df[5:]

# %%
df_filter
# Out:
#        BeerID                                          Name  \
# 5           6                  Sierra Nevada Pale Ale Clone
# 6           7      Russian River Pliny the Elder (original)
# 7           8  Spotted Clown (New Glarus Spotted Cow clone)
# 8           9                      Chocolate Vanilla Porter
# 9          10                            Mango Habanero IPA
# ...       ...                                           ...
# 73856   73857                                 Amber Alfie 2
# 73857   73858                                       Rye IPA
# 73858   73859                                     SK-Kölsch
# 73859   73860                               Flata Rødkløver
# 73860   73861                         Elvis Juice IPA Clone
#
#                                                      URL  \
# 5      /homebrew/recipe/view/28546/sierra-nevada-pale...
# 6      /homebrew/recipe/view/37534/russian-river-plin...
# 7      /homebrew/recipe/view/672/spotted-clown-new-gl...
# 8      /homebrew/recipe/view/29265/chocolate-vanilla-...
# 9         /homebrew/recipe/view/61082/mango-habanero-ipa
# ...                                                  ...
# 73856         /homebrew/recipe/view/609673/amber-alfie-2
# 73857               /homebrew/recipe/view/610955/rye-ipa
# 73858                      /homebrew/recipe/view/586891/
# 73859                      /homebrew/recipe/view/603788/
# 73860  /homebrew/recipe/view/613776/elvis-juice-ipa-c...
#
#                         Style  StyleID  Size(L)     OG     FG   ABV     IBU  \
# 5           American Pale Ale       10    24.61  1.055  1.013  5.58   40.12
# 6                Imperial IPA       86    22.71  1.072  1.018  7.09  268.71
# 7                   Cream Ale       45    20.82  1.054  1.014  5.36   19.97
# 8               Robust Porter      129    22.71  1.060  1.016  5.77   31.63
# 9                Imperial IPA       86    20.82  1.080  1.017  8.22   93.02
# ...                       ...      ...      ...    ...    ...   ...     ...
# 73856      British Strong Ale       36    21.00  1.052  1.012  5.22   39.73
# 73857  Specialty IPA: Rye IPA      151    10.00  1.059  1.010  6.37   59.21
# 73858                     NaN      111    16.00  1.046  1.008  5.01   25.42
# 73859           Irish Red Ale       92    24.00  1.051  1.014  4.82   25.65
# 73860            American IPA        7    20.00  1.060  1.010  6.55   57.09
#
#        ...  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 5      ...        1.047        79.0            NaN  Specific Gravity
# 6      ...          NaN        75.0            NaN  Specific Gravity
# 7      ...        1.040        70.0            1.4  Specific Gravity
# 8      ...        1.042        73.0            NaN  Specific Gravity
# 9      ...        1.058        70.0            NaN  Specific Gravity
# ...    ...          ...         ...            ...               ...
# 73856  ...        1.060        63.0            3.0  Specific Gravity
# 73857  ...        1.034        60.0            NaN  Specific Gravity
# 73858  ...        1.041        65.0            NaN  Specific Gravity
# 73859  ...        1.043        72.0            NaN  Specific Gravity
# 73860  ...        1.056        70.0            NaN  Specific Gravity
#
#          BrewMethod  PitchRate PrimaryTemp PrimingMethod   PrimingAmount  \
# 5         All Grain       1.00         NaN           NaN             NaN
# 6         All Grain        NaN         NaN           NaN             NaN
# 7         All Grain        NaN         NaN    corn sugar          4.2 oz
# 8         All Grain        NaN         NaN    corn sugar            4 oz
# 9         All Grain        NaN       21.11    Corn Sugar  4.6 oz / .66 C
# ...             ...        ...         ...           ...             ...
# 73856     All Grain       1.25       20.00           NaN             NaN
# 73857          BIAB       0.50       22.00           NaN             NaN
# 73858          BIAB       0.35       17.00       sucrose           140 g
# 73859     All Grain        NaN       18.00    Sukkerlake    5 g sukker/l
# 73860  Partial Mash        NaN       18.00           NaN             NaN
#
#         UserId
# 5       5889.0
# 6       1051.0
# 7        116.0
# 8        116.0
# 9          NaN
# ...        ...
# 73856  59658.0
# 73857      NaN
# 73858  82450.0
# 73859      NaN
# 73860      NaN
#
# [73856 rows x 23 columns]

# %%
df_obs=df.drop([2,5,8,9],axis=0)

# %%
df_obs.head(11)
# Out:
#     BeerID                                          Name  \
# 0        1                             Vanilla Cream Ale
# 1        2                   Southern Tier Pumking clone
# 3        4                 Zombie Dust Clone - ALL GRAIN
# 4        5               Bakke Brygg Belgisk Blonde 50 l
# 6        7      Russian River Pliny the Elder (original)
# 7        8  Spotted Clown (New Glarus Spotted Cow clone)
# 10      11                     Bakke Brygg HveteIPA 25 L
# 11      12                               Hop Notch Clone
# 12      13                             Racer 5 IPA Clone
# 13      14                     Sam Adams Rebel IPA Clone
# 14      15                                     White IPA
#
#                                                   URL  \
# 0        /homebrew/recipe/view/1633/vanilla-cream-ale
# 1   /homebrew/recipe/view/16367/southern-tier-pumk...
# 3   /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4   /homebrew/recipe/view/89534/bakke-brygg-belgis...
# 6   /homebrew/recipe/view/37534/russian-river-plin...
# 7   /homebrew/recipe/view/672/spotted-clown-new-gl...
# 10  /homebrew/recipe/view/73890/bakke-brygg-hvetei...
# 11        /homebrew/recipe/view/10092/hop-notch-clone
# 12      /homebrew/recipe/view/23246/racer-5-ipa-clone
# 13  /homebrew/recipe/view/106996/sam-adams-rebel-i...
# 14               /homebrew/recipe/view/8361/white-ipa
#
#                                  Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                            Cream Ale       45    21.77  1.055  1.013  5.48
# 1   Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 3                         American IPA        7    22.71  1.061  1.017  5.80
# 4                    Belgian Blond Ale       20    50.00  1.060  1.010  6.48
# 6                         Imperial IPA       86    22.71  1.072  1.018  7.09
# 7                            Cream Ale       45    20.82  1.054  1.014  5.36
# 10                        American IPA        7    25.00  1.064  1.014  6.63
# 11                        American IPA        7    15.14  1.066  1.015  6.62
# 12                        American IPA        7    20.82  1.073  1.019  7.07
# 13                        American IPA        7    18.93  1.066  1.017  6.51
# 14                        American IPA        7    37.85  1.064  1.017  6.20
#
#        IBU  ...  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 0    17.65  ...        1.038        70.0            NaN  Specific Gravity
# 1    60.65  ...        1.070        70.0            NaN  Specific Gravity
# 3    54.48  ...          NaN        70.0            NaN  Specific Gravity
# 4    17.84  ...        1.050        72.0            NaN  Specific Gravity
# 6   268.71  ...          NaN        75.0            NaN  Specific Gravity
# 7    19.97  ...        1.040        70.0            1.4  Specific Gravity
# 10   64.26  ...        1.055        74.0            NaN  Specific Gravity
# 11  111.00  ...          NaN        70.0            NaN  Specific Gravity
# 12   69.72  ...          NaN        70.0            NaN  Specific Gravity
# 13   60.96  ...        1.110        30.0            NaN  Specific Gravity
# 14   64.67  ...        1.071        70.0            1.2  Specific Gravity
#
#     BrewMethod  PitchRate PrimaryTemp PrimingMethod   PrimingAmount   UserId
# 0    All Grain        NaN       17.78    corn sugar          4.5 oz    116.0
# 1    All Grain        NaN         NaN           NaN             NaN    955.0
# 3    All Grain        NaN         NaN           NaN             NaN      NaN
# 4    All Grain        NaN       19.00    Sukkerlake  6-7 g sukker/l  18325.0
# 6    All Grain        NaN         NaN           NaN             NaN   1051.0
# 7    All Grain        NaN         NaN    corn sugar          4.2 oz    116.0
# 10   All Grain       1.00       18.00    Sukkerlake  6 5 g sukker/L  18325.0
# 11        BIAB        NaN         NaN           NaN             NaN      NaN
# 12   All Grain        NaN         NaN           NaN             NaN      NaN
# 13     extract       0.35       18.33           NaN             NaN  23595.0
# 14   All Grain        NaN         NaN           NaN             NaN      NaN
#
# [11 rows x 23 columns]

# %%
df.shape
# Out:
# (73861, 23)

# %%
# drop these columns ['Name', 'URL', 'Style', 'StyleID', 'Size(L)', 'OG', 'FG']

# %%
df_rcol=df.drop(['Name', 'URL', 'Style', 'StyleID', 'Size(L)', 'OG', 'FG'],axis=1)

# %%
df.head(5)
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  URL  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American IPA        7    18.93  1.063  1.018  5.91
# 3                        American IPA        7    22.71  1.061  1.017  5.80
# 4                   Belgian Blond Ale       20    50.00  1.060  1.010  6.48
#
#      IBU  ...  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 0  17.65  ...        1.038        70.0            NaN  Specific Gravity
# 1  60.65  ...        1.070        70.0            NaN  Specific Gravity
# 2  59.25  ...          NaN        70.0            NaN  Specific Gravity
# 3  54.48  ...          NaN        70.0            NaN  Specific Gravity
# 4  17.84  ...        1.050        72.0            NaN  Specific Gravity
#
#    BrewMethod  PitchRate PrimaryTemp PrimingMethod   PrimingAmount   UserId
# 0   All Grain        NaN       17.78    corn sugar          4.5 oz    116.0
# 1   All Grain        NaN         NaN           NaN             NaN    955.0
# 2     extract        NaN         NaN           NaN             NaN      NaN
# 3   All Grain        NaN         NaN           NaN             NaN      NaN
# 4   All Grain        NaN       19.00    Sukkerlake  6-7 g sukker/l  18325.0
#
# [5 rows x 23 columns]

# %%
df_rcol.head(5)
# Out:
#    BeerID   ABV    IBU  Color  BoilSize  BoilTime  BoilGravity  Efficiency  \
# 0       1  5.48  17.65   4.83     28.39        75        1.038        70.0
# 1       2  8.16  60.65  15.64     24.61        60        1.070        70.0
# 2       3  5.91  59.25   8.98     22.71        60          NaN        70.0
# 3       4  5.80  54.48   8.50     26.50        60          NaN        70.0
# 4       5  6.48  17.84   4.57     60.00        90        1.050        72.0
#
#    MashThickness        SugarScale BrewMethod  PitchRate  PrimaryTemp  \
# 0            NaN  Specific Gravity  All Grain        NaN        17.78
# 1            NaN  Specific Gravity  All Grain        NaN          NaN
# 2            NaN  Specific Gravity    extract        NaN          NaN
# 3            NaN  Specific Gravity  All Grain        NaN          NaN
# 4            NaN  Specific Gravity  All Grain        NaN        19.00
#
#   PrimingMethod   PrimingAmount   UserId
# 0    corn sugar          4.5 oz    116.0
# 1           NaN             NaN    955.0
# 2           NaN             NaN      NaN
# 3           NaN             NaN      NaN
# 4    Sukkerlake  6-7 g sukker/l  18325.0

# %%
dfn=df

# %%
dfn.drop(['Name', 'URL', 'Style', 'StyleID', 'Size(L)', 'OG', 'FG'],axis=1,inplace=True)

# %%
dfn.head()
# Out:
#    BeerID   ABV    IBU  Color  BoilSize  BoilTime  BoilGravity  Efficiency  \
# 0       1  5.48  17.65   4.83     28.39        75        1.038        70.0
# 1       2  8.16  60.65  15.64     24.61        60        1.070        70.0
# 2       3  5.91  59.25   8.98     22.71        60          NaN        70.0
# 3       4  5.80  54.48   8.50     26.50        60          NaN        70.0
# 4       5  6.48  17.84   4.57     60.00        90        1.050        72.0
#
#    MashThickness        SugarScale BrewMethod  PitchRate  PrimaryTemp  \
# 0            NaN  Specific Gravity  All Grain        NaN        17.78
# 1            NaN  Specific Gravity  All Grain        NaN          NaN
# 2            NaN  Specific Gravity    extract        NaN          NaN
# 3            NaN  Specific Gravity  All Grain        NaN          NaN
# 4            NaN  Specific Gravity  All Grain        NaN        19.00
#
#   PrimingMethod   PrimingAmount   UserId
# 0    corn sugar          4.5 oz    116.0
# 1           NaN             NaN    955.0
# 2           NaN             NaN      NaN
# 3           NaN             NaN      NaN
# 4    Sukkerlake  6-7 g sukker/l  18325.0

# %%
# consider the columns ['Name', 'URL', 'Style', 'StyleID']

# %%
dfs=df[['Name', 'URL', 'Style', 'StyleID']]

# %%
#sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)

# %%
# dfs.Style.value_counts()

# %%
#sort Style columns in ascending order
#sort Style columns in make missing values in first posting

# %%
df_stylosort=dfs.sort_values(by=['Style'],na_position='first')

# %%
df_stylosort=dfs.sort_values(by=['Style'],ascending=False)

# %%
df_stylosort
# Out:
#                           Name  \
# 22071  RIS Barrel project 2016
# 52804                 Reds Red
# 9453      Fist Full of Tequila
# 922                 Peat & Oak
# 3580      SchuBrew BBQ Project
# ...                        ...
# 73413            Summer saison
# 73600                Cara  Red
# 73634          Wit Easter Beer
# 73700        Chinook the Crook
# 73858                SK-Kölsch
#
#                                                      URL           Style  \
# 22071  /homebrew/recipe/view/403639/ris-barrel-projec...  Wood-Aged Beer
# 52804              /homebrew/recipe/view/545208/reds-red  Wood-Aged Beer
# 9453   /homebrew/recipe/view/241382/fist-full-of-tequila  Wood-Aged Beer
# 922                 /homebrew/recipe/view/38965/peat-oak  Wood-Aged Beer
# 3580   /homebrew/recipe/view/187685/schubrew-bbq-project  Wood-Aged Beer
# ...                                                  ...             ...
# 73413         /homebrew/recipe/view/617449/summer-saison             NaN
# 73600              /homebrew/recipe/view/614632/cara-red             NaN
# 73634       /homebrew/recipe/view/611645/wit-easter-beer             NaN
# 73700     /homebrew/recipe/view/615888/chinook-the-crook             NaN
# 73858                      /homebrew/recipe/view/586891/             NaN
#
#        StyleID
# 22071      176
# 52804      176
# 9453       176
# 922        176
# 3580       176
# ...        ...
# 73413      111
# 73600      111
# 73634      111
# 73700      111
# 73858      111
#
# [73861 rows x 4 columns]

# %%
#remove the duplicates in "Name" column
#keep the last observations

# %%
#drop_duplicates(subset=None/['var1','var2'], keep='first/last', inplace=False/True, ignore_index=False/True)

# %%
dfdup=df

# %%
dfdup.shape
# Out:
# (73861, 23)

# %%
dfdup.drop_duplicates(subset=['Style'],keep='first',inplace=True)

# %%
dfdup.shape
# Out:
# (176, 23)

# %%
df_dropcol=drop()
df_dropcol_sor=df_dropcol.sort_values()
df_dropcol_sor_dup=df_dropcol_sor.drop_duplicates()

# %%
dfdup_rndup.shape
# Out:
# (176, 23)

# %%
dfdup_rndup.sort_values(by='Style')
# Out:
#       BeerID                                           Name  \
# 246      247                           #56 Ringwood Romance
# 1981    1982                                     Dutch Kuyt
# 4268    4269            Kümmel  (Caraway Liqueur) "Brewers"
# 48        49                            Nugget Nectar Clone
# 509      510                           American Barley Wine
# ...      ...                                            ...
# 1733    1734                                 Raspberry sour
# 139      140                Great Lakes Christmas Ale Clone
# 50        51  Kronenbourg Blanc clone (Été dans un verre...
# 150      151                    Kentucky Bourbon Barrel Ale
# 38        39                              Rochefort 8 Clone
#
#                                                     URL  \
# 246   /homebrew/recipe/view/140909/-56-ringwood-romance
# 1981            /homebrew/recipe/view/318705/dutch-kuyt
# 4268                      /homebrew/recipe/view/306192/
# 48     /homebrew/recipe/view/189197/nugget-nectar-clone
# 509    /homebrew/recipe/view/11296/american-barley-wine
# ...                                                 ...
# 1733        /homebrew/recipe/view/307411/raspberry-sour
# 139   /homebrew/recipe/view/282437/great-lakes-chris...
# 50                        /homebrew/recipe/view/182011/
# 150   /homebrew/recipe/view/74737/kentucky-bourbon-b...
# 38       /homebrew/recipe/view/188995/rochefort-8-clone
#
#                        Style  StyleID  Size(L)     OG     FG    ABV     IBU  \
# 246                  Altbier        1     9.46  1.055  1.015   5.23   21.66
# 1981  Alternative Grain Beer        2    11.36  1.043  1.011   4.24   27.80
# 4268  Alternative Sugar Beer        3     2.84  1.184  1.035  19.56    0.00
# 48        American Amber Ale        4    18.93  1.075  1.009   7.50    0.00
# 509      American Barleywine        5    22.71  1.110  1.022  11.58  146.28
# ...                      ...      ...      ...    ...    ...    ...     ...
# 1733     Wild Specialty Beer      173     6.81  1.058  1.011   6.09   12.82
# 139     Winter Seasonal Beer      174    22.71  1.072  1.017   7.31   28.98
# 50                   Witbier      175    18.93  1.051  1.012   5.22   18.67
# 150           Wood-Aged Beer      176    18.93  1.099  1.033   8.62   20.79
# 38                       NaN      111    18.93  1.079  1.019   7.90    0.00
#
#       ...  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 246   ...        1.046        35.0            NaN  Specific Gravity
# 1981  ...        1.026        70.0            NaN  Specific Gravity
# 4268  ...        1.184        35.0            NaN  Specific Gravity
# 48    ...          NaN        70.0            NaN  Specific Gravity
# 509   ...          NaN        74.0            NaN  Specific Gravity
# ...   ...          ...         ...            ...               ...
# 1733  ...        1.035        70.0            NaN  Specific Gravity
# 139   ...        1.053        70.0            NaN  Specific Gravity
# 50    ...        1.035        68.0           1.25  Specific Gravity
# 150   ...        1.082        70.0           1.25  Specific Gravity
# 38    ...          NaN        65.0            NaN  Specific Gravity
#
#       BrewMethod  PitchRate PrimaryTemp  PrimingMethod  PrimingAmount   UserId
# 246      extract       0.75       23.33            NaN            NaN      NaN
# 1981   All Grain       0.50       16.67            NaN            NaN      NaN
# 4268     extract        NaN         NaN            NaN            NaN  42159.0
# 48     All Grain        NaN         NaN            NaN            NaN      NaN
# 509    All Grain        NaN         NaN            NaN            NaN   1569.0
# ...          ...        ...         ...            ...            ...      ...
# 1733        BIAB       0.75       20.00            NaN            NaN      NaN
# 139         BIAB       0.35       21.11            NaN            NaN  39433.0
# 50     All Grain       0.75       20.00            NaN            NaN  13114.0
# 150    All Grain        NaN       20.00  priming sugar          7 ozs      NaN
# 38     All Grain        NaN         NaN            NaN            NaN      NaN
#
# [176 rows x 23 columns]

# %%
dfdup_rndup
# Out:
#        BeerID                             Name  \
# 0           1                Vanilla Cream Ale
# 1           2      Southern Tier Pumking clone
# 2           3      Zombie Dust Clone - EXTRACT
# 4           5  Bakke Brygg Belgisk Blonde 50 l
# 5           6     Sierra Nevada Pale Ale Clone
# ...       ...                              ...
# 7173     7174                 Uff-da Clone-ish
# 7507     7508                       Kottbusser
# 7716     7717           Scotch Ale 90 Shilling
# 7879     7880                      1871 Porter
# 11071   11072               Bourbon Baby Stout
#
#                                                      URL  \
# 0           /homebrew/recipe/view/1633/vanilla-cream-ale
# 1      /homebrew/recipe/view/16367/southern-tier-pumk...
# 2      /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 4      /homebrew/recipe/view/89534/bakke-brygg-belgis...
# 5      /homebrew/recipe/view/28546/sierra-nevada-pale...
# ...                                                  ...
# 7173       /homebrew/recipe/view/312770/uff-da-clone-ish
# 7507             /homebrew/recipe/view/312933/kottbusser
# 7716   /homebrew/recipe/view/347779/scotch-ale-90-shi...
# 7879            /homebrew/recipe/view/414675/1871-porter
# 11071    /homebrew/recipe/view/309705/bourbon-baby-stout
#
#                                     Style  StyleID  Size(L)     OG     FG  \
# 0                               Cream Ale       45    21.77  1.055  1.013
# 1      Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021
# 2                            American IPA        7    18.93  1.063  1.018
# 4                       Belgian Blond Ale       20    50.00  1.060  1.010
# 5                       American Pale Ale       10    24.61  1.055  1.013
# ...                                   ...      ...      ...    ...    ...
# 7173                         Dunkles Bock       60    20.82  1.065  1.018
# 7507                    German Leichtbier       79    21.77  1.054  1.013
# 7716                       Scottish Light      140    18.93  1.109  1.032
# 7879               Pre-Prohibition Porter      126    22.71  1.049  1.012
# 11071            Specialty Wood-Aged Beer      154    18.93  1.106  1.021
#
#          ABV     IBU  ...  BoilGravity  Efficiency  MashThickness  \
# 0       5.48   17.65  ...        1.038        70.0            NaN
# 1       8.16   60.65  ...        1.070        70.0            NaN
# 2       5.91   59.25  ...          NaN        70.0            NaN
# 4       6.48   17.84  ...        1.050        72.0            NaN
# 5       5.58   40.12  ...        1.047        79.0            NaN
# ...      ...     ...  ...          ...         ...            ...
# 7173    6.45   28.58  ...        1.048        75.0            NaN
# 7507    5.40   32.16  ...        1.044        65.0           1.75
# 7716   10.05   30.68  ...        1.084        70.0           1.25
# 7879    4.88   28.71  ...        1.039        73.0           1.50
# 11071  11.25  106.60  ...        1.071        65.0           1.50
#
#              SugarScale  BrewMethod  PitchRate PrimaryTemp PrimingMethod  \
# 0      Specific Gravity   All Grain        NaN       17.78    corn sugar
# 1      Specific Gravity   All Grain        NaN         NaN           NaN
# 2      Specific Gravity     extract        NaN         NaN           NaN
# 4      Specific Gravity   All Grain        NaN       19.00    Sukkerlake
# 5      Specific Gravity   All Grain       1.00         NaN           NaN
# ...                 ...         ...        ...         ...           ...
# 7173   Specific Gravity        BIAB       1.50        8.89           NaN
# 7507   Specific Gravity   All Grain       0.75       17.22           NaN
# 7716   Specific Gravity   All Grain       1.25       20.00           NaN
# 7879   Specific Gravity   All Grain       0.75       20.00           NaN
# 11071  Specific Gravity   All Grain       1.25       21.11      Molassas
#
#         PrimingAmount   UserId
# 0              4.5 oz    116.0
# 1                 NaN    955.0
# 2                 NaN      NaN
# 4      6-7 g sukker/l  18325.0
# 5                 NaN   5889.0
# ...               ...      ...
# 7173              NaN  10483.0
# 7507              NaN   8496.0
# 7716              NaN      NaN
# 7879              NaN  39583.0
# 11071           1 cup      NaN
#
# [176 rows x 23 columns]

# %%
df.sort_values(by='Style')
# Out:
#        BeerID                     Name  \
# 45708   45709      Rhine River Altbier
# 38728   38729  Son of an ALTered Beast
# 10507   10508                  AltBier
# 37081   37082          Alt  Dusseldorf
# 69732   69733            JZ Cowboy Alt
# ...       ...                      ...
# 73413   73414            Summer saison
# 73600   73601                Cara  Red
# 73634   73635          Wit Easter Beer
# 73700   73701        Chinook the Crook
# 73858   73859                SK-Kölsch
#
#                                                      URL    Style  StyleID  \
# 45708   /homebrew/recipe/view/438268/rhine-river-altbier  Altbier        1
# 38728  /homebrew/recipe/view/452011/son-of-an-altered...  Altbier        1
# 10507               /homebrew/recipe/view/307150/altbier  Altbier        1
# 37081        /homebrew/recipe/view/372046/alt-dusseldorf  Altbier        1
# 69732         /homebrew/recipe/view/601105/jz-cowboy-alt  Altbier        1
# ...                                                  ...      ...      ...
# 73413         /homebrew/recipe/view/617449/summer-saison      NaN      111
# 73600              /homebrew/recipe/view/614632/cara-red      NaN      111
# 73634       /homebrew/recipe/view/611645/wit-easter-beer      NaN      111
# 73700     /homebrew/recipe/view/615888/chinook-the-crook      NaN      111
# 73858                      /homebrew/recipe/view/586891/      NaN      111
#
#        Size(L)     OG     FG   ABV    IBU  ...  BoilGravity  Efficiency  \
# 45708    18.93  1.050  1.010  5.34  52.65  ...        1.043        68.0
# 38728    20.82  1.050  1.016  4.47  40.15  ...        1.042        68.0
# 10507    18.93  1.052  1.012  5.19  96.83  ...        1.037        70.0
# 37081    28.39  1.052  1.012  5.30  42.03  ...        1.041        70.0
# 69732    22.00  1.051  1.012  5.13  41.36  ...        1.042        70.0
# ...        ...    ...    ...   ...    ...  ...          ...         ...
# 73413    18.93  1.064  1.019  5.84  31.69  ...        1.106        35.0
# 73600    22.71  1.046  1.010  4.61  68.81  ...        1.037        70.0
# 73634    21.00  1.025  1.006  2.52   7.43  ...        1.018        35.0
# 73700    20.82  1.055  1.010  5.90  68.19  ...        1.043        75.0
# 73858    16.00  1.046  1.008  5.01  25.42  ...        1.041        65.0
#
#        MashThickness        SugarScale  BrewMethod  PitchRate PrimaryTemp  \
# 45708           1.25  Specific Gravity   All Grain        NaN         NaN
# 38728           1.25  Specific Gravity   All Grain        NaN         NaN
# 10507           1.50  Specific Gravity   All Grain        NaN       20.00
# 37081           1.60  Specific Gravity   All Grain        NaN         NaN
# 69732           2.50  Specific Gravity   All Grain       1.25       16.00
# ...              ...               ...         ...        ...         ...
# 73413            NaN  Specific Gravity     extract        NaN       20.00
# 73600           1.50  Specific Gravity   All Grain        NaN         NaN
# 73634            NaN  Specific Gravity        BIAB        NaN       20.00
# 73700           1.50  Specific Gravity   All Grain       0.50       22.22
# 73858            NaN  Specific Gravity        BIAB       0.35       17.00
#
#       PrimingMethod  PrimingAmount    UserId
# 45708           NaN            NaN       NaN
# 38728           NaN            NaN       NaN
# 10507           NaN            NaN     603.0
# 37081           NaN            NaN       NaN
# 69732           NaN            NaN       NaN
# ...             ...            ...       ...
# 73413           NaN            NaN  130414.0
# 73600           NaN            NaN   53199.0
# 73634           NaN            NaN       NaN
# 73700           NaN            NaN       NaN
# 73858       sucrose          140 g   82450.0
#
# [73861 rows x 23 columns]

# %%
#reset index
#drop index columns
#reset index in same data frame

# %%
#reset_index(level=None, drop=False/True, inplace=False/true, col_level=0, col_fill='')

# %%
dff=df

# %%
# dfdup_rndup.shape
df_reset_ind=dfdup_rndup.reset_index()

# %%
df_reset_ind_n=dfdup_rndup.reset_index(drop=True)

# %%
dfdup_rndup.reset_index(inplace=True)

# %%
dfdup_rndup
# Out:
#      index  BeerID                             Name  \
# 0        0       1                Vanilla Cream Ale
# 1        1       2      Southern Tier Pumking clone
# 2        2       3      Zombie Dust Clone - EXTRACT
# 3        4       5  Bakke Brygg Belgisk Blonde 50 l
# 4        5       6     Sierra Nevada Pale Ale Clone
# ..     ...     ...                              ...
# 171   7173    7174                 Uff-da Clone-ish
# 172   7507    7508                       Kottbusser
# 173   7716    7717           Scotch Ale 90 Shilling
# 174   7879    7880                      1871 Porter
# 175  11071   11072               Bourbon Baby Stout
#
#                                                    URL  \
# 0         /homebrew/recipe/view/1633/vanilla-cream-ale
# 1    /homebrew/recipe/view/16367/southern-tier-pumk...
# 2    /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3    /homebrew/recipe/view/89534/bakke-brygg-belgis...
# 4    /homebrew/recipe/view/28546/sierra-nevada-pale...
# ..                                                 ...
# 171      /homebrew/recipe/view/312770/uff-da-clone-ish
# 172            /homebrew/recipe/view/312933/kottbusser
# 173  /homebrew/recipe/view/347779/scotch-ale-90-shi...
# 174           /homebrew/recipe/view/414675/1871-porter
# 175    /homebrew/recipe/view/309705/bourbon-baby-stout
#
#                                   Style  StyleID  Size(L)     OG     FG  \
# 0                             Cream Ale       45    21.77  1.055  1.013
# 1    Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021
# 2                          American IPA        7    18.93  1.063  1.018
# 3                     Belgian Blond Ale       20    50.00  1.060  1.010
# 4                     American Pale Ale       10    24.61  1.055  1.013
# ..                                  ...      ...      ...    ...    ...
# 171                        Dunkles Bock       60    20.82  1.065  1.018
# 172                   German Leichtbier       79    21.77  1.054  1.013
# 173                      Scottish Light      140    18.93  1.109  1.032
# 174              Pre-Prohibition Porter      126    22.71  1.049  1.012
# 175            Specialty Wood-Aged Beer      154    18.93  1.106  1.021
#
#        ABV  ...  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 0     5.48  ...        1.038        70.0            NaN  Specific Gravity
# 1     8.16  ...        1.070        70.0            NaN  Specific Gravity
# 2     5.91  ...          NaN        70.0            NaN  Specific Gravity
# 3     6.48  ...        1.050        72.0            NaN  Specific Gravity
# 4     5.58  ...        1.047        79.0            NaN  Specific Gravity
# ..     ...  ...          ...         ...            ...               ...
# 171   6.45  ...        1.048        75.0            NaN  Specific Gravity
# 172   5.40  ...        1.044        65.0           1.75  Specific Gravity
# 173  10.05  ...        1.084        70.0           1.25  Specific Gravity
# 174   4.88  ...        1.039        73.0           1.50  Specific Gravity
# 175  11.25  ...        1.071        65.0           1.50  Specific Gravity
#
#      BrewMethod  PitchRate  PrimaryTemp PrimingMethod   PrimingAmount   UserId
# 0     All Grain        NaN        17.78    corn sugar          4.5 oz    116.0
# 1     All Grain        NaN          NaN           NaN             NaN    955.0
# 2       extract        NaN          NaN           NaN             NaN      NaN
# 3     All Grain        NaN        19.00    Sukkerlake  6-7 g sukker/l  18325.0
# 4     All Grain       1.00          NaN           NaN             NaN   5889.0
# ..          ...        ...          ...           ...             ...      ...
# 171        BIAB       1.50         8.89           NaN             NaN  10483.0
# 172   All Grain       0.75        17.22           NaN             NaN   8496.0
# 173   All Grain       1.25        20.00           NaN             NaN      NaN
# 174   All Grain       0.75        20.00           NaN             NaN  39583.0
# 175   All Grain       1.25        21.11      Molassas           1 cup      NaN
#
# [176 rows x 24 columns]

# %%
df_reset_ind_n
# Out:
#      BeerID                             Name  \
# 0         1                Vanilla Cream Ale
# 1         2      Southern Tier Pumking clone
# 2         3      Zombie Dust Clone - EXTRACT
# 3         5  Bakke Brygg Belgisk Blonde 50 l
# 4         6     Sierra Nevada Pale Ale Clone
# ..      ...                              ...
# 171    7174                 Uff-da Clone-ish
# 172    7508                       Kottbusser
# 173    7717           Scotch Ale 90 Shilling
# 174    7880                      1871 Porter
# 175   11072               Bourbon Baby Stout
#
#                                                    URL  \
# 0         /homebrew/recipe/view/1633/vanilla-cream-ale
# 1    /homebrew/recipe/view/16367/southern-tier-pumk...
# 2    /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3    /homebrew/recipe/view/89534/bakke-brygg-belgis...
# 4    /homebrew/recipe/view/28546/sierra-nevada-pale...
# ..                                                 ...
# 171      /homebrew/recipe/view/312770/uff-da-clone-ish
# 172            /homebrew/recipe/view/312933/kottbusser
# 173  /homebrew/recipe/view/347779/scotch-ale-90-shi...
# 174           /homebrew/recipe/view/414675/1871-porter
# 175    /homebrew/recipe/view/309705/bourbon-baby-stout
#
#                                   Style  StyleID  Size(L)     OG     FG  \
# 0                             Cream Ale       45    21.77  1.055  1.013
# 1    Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021
# 2                          American IPA        7    18.93  1.063  1.018
# 3                     Belgian Blond Ale       20    50.00  1.060  1.010
# 4                     American Pale Ale       10    24.61  1.055  1.013
# ..                                  ...      ...      ...    ...    ...
# 171                        Dunkles Bock       60    20.82  1.065  1.018
# 172                   German Leichtbier       79    21.77  1.054  1.013
# 173                      Scottish Light      140    18.93  1.109  1.032
# 174              Pre-Prohibition Porter      126    22.71  1.049  1.012
# 175            Specialty Wood-Aged Beer      154    18.93  1.106  1.021
#
#        ABV     IBU  ...  BoilGravity  Efficiency  MashThickness  \
# 0     5.48   17.65  ...        1.038        70.0            NaN
# 1     8.16   60.65  ...        1.070        70.0            NaN
# 2     5.91   59.25  ...          NaN        70.0            NaN
# 3     6.48   17.84  ...        1.050        72.0            NaN
# 4     5.58   40.12  ...        1.047        79.0            NaN
# ..     ...     ...  ...          ...         ...            ...
# 171   6.45   28.58  ...        1.048        75.0            NaN
# 172   5.40   32.16  ...        1.044        65.0           1.75
# 173  10.05   30.68  ...        1.084        70.0           1.25
# 174   4.88   28.71  ...        1.039        73.0           1.50
# 175  11.25  106.60  ...        1.071        65.0           1.50
#
#            SugarScale  BrewMethod  PitchRate PrimaryTemp PrimingMethod  \
# 0    Specific Gravity   All Grain        NaN       17.78    corn sugar
# 1    Specific Gravity   All Grain        NaN         NaN           NaN
# 2    Specific Gravity     extract        NaN         NaN           NaN
# 3    Specific Gravity   All Grain        NaN       19.00    Sukkerlake
# 4    Specific Gravity   All Grain       1.00         NaN           NaN
# ..                ...         ...        ...         ...           ...
# 171  Specific Gravity        BIAB       1.50        8.89           NaN
# 172  Specific Gravity   All Grain       0.75       17.22           NaN
# 173  Specific Gravity   All Grain       1.25       20.00           NaN
# 174  Specific Gravity   All Grain       0.75       20.00           NaN
# 175  Specific Gravity   All Grain       1.25       21.11      Molassas
#
#       PrimingAmount   UserId
# 0            4.5 oz    116.0
# 1               NaN    955.0
# 2               NaN      NaN
# 3    6-7 g sukker/l  18325.0
# 4               NaN   5889.0
# ..              ...      ...
# 171             NaN  10483.0
# 172             NaN   8496.0
# 173             NaN      NaN
# 174             NaN  39583.0
# 175           1 cup      NaN
#
# [176 rows x 23 columns]

# %%
# dfn=pd.read_csv(r"C:\Users\ppulivarthi\AV_Hackthons\Janathahack_HR_Analytics\train_jqd04QH.csv")

# %% [markdown]
# # Identifying Missing values

# %%
#isnull(),isna,notna()

# %%
# syntax:
# pd.isnull(obj)
# df.isnull()

# %%
df.head(5)
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  URL  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American IPA        7    18.93  1.063  1.018  5.91
# 3                        American IPA        7    22.71  1.061  1.017  5.80
# 4                   Belgian Blond Ale       20    50.00  1.060  1.010  6.48
#
#      IBU  ...  BoilGravity  Efficiency  MashThickness        SugarScale  \
# 0  17.65  ...        1.038        70.0            NaN  Specific Gravity
# 1  60.65  ...        1.070        70.0            NaN  Specific Gravity
# 2  59.25  ...          NaN        70.0            NaN  Specific Gravity
# 3  54.48  ...          NaN        70.0            NaN  Specific Gravity
# 4  17.84  ...        1.050        72.0            NaN  Specific Gravity
#
#    BrewMethod  PitchRate PrimaryTemp PrimingMethod   PrimingAmount   UserId
# 0   All Grain        NaN       17.78    corn sugar          4.5 oz    116.0
# 1   All Grain        NaN         NaN           NaN             NaN    955.0
# 2     extract        NaN         NaN           NaN             NaN      NaN
# 3   All Grain        NaN         NaN           NaN             NaN      NaN
# 4   All Grain        NaN       19.00    Sukkerlake  6-7 g sukker/l  18325.0
#
# [5 rows x 23 columns]

# %%
df.isnull()
# Out:
#        BeerID   Name    URL  Style  StyleID  Size(L)     OG     FG    ABV  \
# 0       False  False  False  False    False    False  False  False  False
# 1       False  False  False  False    False    False  False  False  False
# 2       False  False  False  False    False    False  False  False  False
# 3       False  False  False  False    False    False  False  False  False
# 4       False  False  False  False    False    False  False  False  False
# ...       ...    ...    ...    ...      ...      ...    ...    ...    ...
# 73856   False  False  False  False    False    False  False  False  False
# 73857   False  False  False  False    False    False  False  False  False
# 73858   False  False  False   True    False    False  False  False  False
# 73859   False  False  False  False    False    False  False  False  False
# 73860   False  False  False  False    False    False  False  False  False
#
#          IBU  ...  BoilGravity  Efficiency  MashThickness  SugarScale  \
# 0      False  ...        False       False           True       False
# 1      False  ...        False       False           True       False
# 2      False  ...         True       False           True       False
# 3      False  ...         True       False           True       False
# 4      False  ...        False       False           True       False
# ...      ...  ...          ...         ...            ...         ...
# 73856  False  ...        False       False          False       False
# 73857  False  ...        False       False           True       False
# 73858  False  ...        False       False           True       False
# 73859  False  ...        False       False           True       False
# 73860  False  ...        False       False           True       False
#
#        BrewMethod  PitchRate  PrimaryTemp  PrimingMethod  PrimingAmount  \
# 0           False       True        False          False          False
# 1           False       True         True           True           True
# 2           False       True         True           True           True
# 3           False       True         True           True           True
# 4           False       True        False          False          False
# ...           ...        ...          ...            ...            ...
# 73856       False      False        False           True           True
# 73857       False      False        False           True           True
# 73858       False      False        False          False          False
# 73859       False       True        False          False          False
# 73860       False       True        False           True           True
#
#        UserId
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
# ...       ...
# 73856   False
# 73857    True
# 73858   False
# 73859    True
# 73860    True
#
# [73861 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# BeerID               0
# Name                 1
# URL                  0
# Style              596
# StyleID              0
# Size(L)              0
# OG                   0
# FG                   0
# ABV                  0
# IBU                  0
# Color                0
# BoilSize             0
# BoilTime             0
# BoilGravity       2990
# Efficiency           0
# MashThickness    29864
# SugarScale           0
# BrewMethod           0
# PitchRate        39252
# PrimaryTemp      22662
# PrimingMethod    67095
# PrimingAmount    69087
# UserId           50490
# dtype: int64

# %%
# df=pd.read_csv(r"C:\Users\ppulivarthi\AV_Hackthons\Janathahack_HR_Analytics\train_jqd04QH.csv")

# %%
# df=pd.read_csv(r"C:\Paramatma_Pulivarthi\Data_Science_course\recipeData.csv",encoding='latin-1')

# %% [markdown]
# # Imputation of missing values or Replacing missing values

# %%
# syntax:
# fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)
# intepolate()
# asfreq()
#sklearn. SimpleImputer(*, missing_values=nan, strategy='mean/median/most_frequent/constant', fill_value=None, verbose=0, copy=True, add_indicator=False)
# fit_transform(df)
# transform(df)

# %%
#find all missing columns values
#Generate the no.of row is missing in each columns

# %%
df.isnull().sum()
# Out:
# BeerID               0
# Name                 1
# URL                  0
# Style              596
# StyleID              0
# Size(L)              0
# OG                   0
# FG                   0
# ABV                  0
# IBU                  0
# Color                0
# BoilSize             0
# BoilTime             0
# BoilGravity       2990
# Efficiency           0
# MashThickness    29864
# SugarScale           0
# BrewMethod           0
# PitchRate        39252
# PrimaryTemp      22662
# PrimingMethod    67095
# PrimingAmount    69087
# UserId           50490
# dtype: int64

# %%
df.isna().sum()
# Out:
# BeerID               0
# Name                 1
# URL                  0
# Style              596
# StyleID              0
# Size(L)              0
# OG                   0
# FG                   0
# ABV                  0
# IBU                  0
# Color                0
# BoilSize             0
# BoilTime             0
# BoilGravity       2990
# Efficiency           0
# MashThickness    29864
# SugarScale           0
# BrewMethod           0
# PitchRate        39252
# PrimaryTemp      22662
# PrimingMethod    67095
# PrimingAmount    69087
# UserId           50490
# dtype: int64

# %%
df.notna()
# Out:
#        BeerID  Name   URL  Style  StyleID  Size(L)    OG    FG   ABV   IBU  \
# 0        True  True  True   True     True     True  True  True  True  True
# 1        True  True  True   True     True     True  True  True  True  True
# 2        True  True  True   True     True     True  True  True  True  True
# 3        True  True  True   True     True     True  True  True  True  True
# 4        True  True  True   True     True     True  True  True  True  True
# ...       ...   ...   ...    ...      ...      ...   ...   ...   ...   ...
# 73856    True  True  True   True     True     True  True  True  True  True
# 73857    True  True  True   True     True     True  True  True  True  True
# 73858    True  True  True  False     True     True  True  True  True  True
# 73859    True  True  True   True     True     True  True  True  True  True
# 73860    True  True  True   True     True     True  True  True  True  True
#
#        ...  BoilGravity  Efficiency  MashThickness  SugarScale  BrewMethod  \
# 0      ...         True        True          False        True        True
# 1      ...         True        True          False        True        True
# 2      ...        False        True          False        True        True
# 3      ...        False        True          False        True        True
# 4      ...         True        True          False        True        True
# ...    ...          ...         ...            ...         ...         ...
# 73856  ...         True        True           True        True        True
# 73857  ...         True        True          False        True        True
# 73858  ...         True        True          False        True        True
# 73859  ...         True        True          False        True        True
# 73860  ...         True        True          False        True        True
#
#        PitchRate  PrimaryTemp  PrimingMethod  PrimingAmount  UserId
# 0          False         True           True           True    True
# 1          False        False          False          False    True
# 2          False        False          False          False   False
# 3          False        False          False          False   False
# 4          False         True           True           True    True
# ...          ...          ...            ...            ...     ...
# 73856       True         True          False          False    True
# 73857       True         True          False          False   False
# 73858       True         True           True           True    True
# 73859      False         True           True           True   False
# 73860      False         True          False          False   False
#
# [73861 rows x 23 columns]

# %%
df.notna().sum()
# Out:
# BeerID           73861
# Name             73860
# URL              73861
# Style            73265
# StyleID          73861
# Size(L)          73861
# OG               73861
# FG               73861
# ABV              73861
# IBU              73861
# Color            73861
# BoilSize         73861
# BoilTime         73861
# BoilGravity      70871
# Efficiency       73861
# MashThickness    43997
# SugarScale       73861
# BrewMethod       73861
# PitchRate        34609
# PrimaryTemp      51199
# PrimingMethod     6766
# PrimingAmount     4774
# UserId           23371
# dtype: int64

# %%
#calculate the percentage of missing values & remove more than 40% missing values

# %%
df_missing=pd.DataFrame(df.isnull().sum(),columns=["missing_data"])

# %%
df_missing['Total_rec']=df.shape[0]

# %%
df_missing['per']=round(((df_missing.missing_data/df_missing.Total_rec)*100),1)

# %%
df_missing
# Out:
#                missing_data  Total_rec   per
# BeerID                    0      73861   0.0
# Name                      1      73861   0.0
# URL                       0      73861   0.0
# Style                   596      73861   0.8
# StyleID                   0      73861   0.0
# Size(L)                   0      73861   0.0
# OG                        0      73861   0.0
# FG                        0      73861   0.0
# ABV                       0      73861   0.0
# IBU                       0      73861   0.0
# Color                     0      73861   0.0
# BoilSize                  0      73861   0.0
# BoilTime                  0      73861   0.0
# BoilGravity            2990      73861   4.0
# Efficiency                0      73861   0.0
# MashThickness         29864      73861  40.4
# SugarScale                0      73861   0.0
# BrewMethod                0      73861   0.0
# PitchRate             39252      73861  53.1
# PrimaryTemp           22662      73861  30.7
# PrimingMethod         67095      73861  90.8
# PrimingAmount         69087      73861  93.5
# UserId                50490      73861  68.4

# %%
#replace missing values with 0
# ['BoilGravity','MashThickness','PitchRate','PrimaryTemp','PrimingMethod','PrimingAmount','UserId','Style']

# %%
df_miss=df[['BoilGravity','MashThickness','PitchRate','PrimaryTemp','PrimingMethod','PrimingAmount','UserId','Style']]

# %%
# df_miss.columns
df_miss.head()
# Out:
#    BoilGravity  MashThickness  PitchRate  PrimaryTemp PrimingMethod  \
# 0        1.038            NaN        NaN        17.78    corn sugar
# 1        1.070            NaN        NaN          NaN           NaN
# 2          NaN            NaN        NaN          NaN           NaN
# 3          NaN            NaN        NaN          NaN           NaN
# 4        1.050            NaN        NaN        19.00    Sukkerlake
#
#     PrimingAmount   UserId                               Style
# 0          4.5 oz    116.0                           Cream Ale
# 1             NaN    955.0  Holiday/Winter Special Spiced Beer
# 2             NaN      NaN                        American IPA
# 3             NaN      NaN                        American IPA
# 4  6-7 g sukker/l  18325.0                   Belgian Blond Ale

# %%
# fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)

# %%
df_miss.head()
# Out:
#    BoilGravity  MashThickness  PitchRate  PrimaryTemp PrimingMethod  \
# 0        1.038            NaN        NaN        17.78    corn sugar
# 1        1.070            NaN        NaN          NaN           NaN
# 2          NaN            NaN        NaN          NaN           NaN
# 3          NaN            NaN        NaN          NaN           NaN
# 4        1.050            NaN        NaN        19.00    Sukkerlake
#
#     PrimingAmount   UserId                               Style
# 0          4.5 oz    116.0                           Cream Ale
# 1             NaN    955.0  Holiday/Winter Special Spiced Beer
# 2             NaN      NaN                        American IPA
# 3             NaN      NaN                        American IPA
# 4  6-7 g sukker/l  18325.0                   Belgian Blond Ale

# %%
# df_miss.fillna(0)
# df_miss_l=df_miss.fillna(0,limit=4)
# 
df_miss_l.head(10)
# Out:
#    BoilGravity  MashThickness  PitchRate  PrimaryTemp PrimingMethod  \
# 0        1.038            0.0        0.0        17.78    corn sugar
# 1        1.070            0.0        0.0         0.00             0
# 2        0.000            0.0        0.0         0.00             0
# 3        0.000            0.0        0.0         0.00             0
# 4        1.050            NaN        NaN        19.00    Sukkerlake
# 5        1.047            NaN        1.0         0.00             0
# 6        0.000            NaN        NaN          NaN           NaN
# 7        1.040            1.4        NaN          NaN    corn sugar
# 8        1.042            NaN        NaN          NaN    corn sugar
# 9        1.058            NaN        NaN        21.11    Corn Sugar
#
#     PrimingAmount   UserId                               Style
# 0          4.5 oz    116.0                           Cream Ale
# 1               0    955.0  Holiday/Winter Special Spiced Beer
# 2               0      0.0                        American IPA
# 3               0      0.0                        American IPA
# 4  6-7 g sukker/l  18325.0                   Belgian Blond Ale
# 5               0   5889.0                   American Pale Ale
# 6             NaN   1051.0                        Imperial IPA
# 7          4.2 oz    116.0                           Cream Ale
# 8            4 oz    116.0                       Robust Porter
# 9  4.6 oz / .66 C      0.0                        Imperial IPA

# %%
#replace missing values with ' '

# %%
df_mis_space=df_miss.fillna(' ')

# %%
df_mis_space
# Out:
#       BoilGravity MashThickness PitchRate PrimaryTemp PrimingMethod  \
# 0           1.038                               17.78    corn sugar
# 1            1.07
# 2
# 3
# 4            1.05                                  19    Sukkerlake
# ...           ...           ...       ...         ...           ...
# 73856        1.06             3      1.25          20
# 73857       1.034                     0.5          22
# 73858       1.041                    0.35          17       sucrose
# 73859       1.043                                  18    Sukkerlake
# 73860       1.056                                  18
#
#         PrimingAmount UserId                               Style
# 0              4.5 oz    116                           Cream Ale
# 1                        955  Holiday/Winter Special Spiced Beer
# 2                                                   American IPA
# 3                                                   American IPA
# 4      6-7 g sukker/l  18325                   Belgian Blond Ale
# ...               ...    ...                                 ...
# 73856                  59658                  British Strong Ale
# 73857                                     Specialty IPA: Rye IPA
# 73858           140 g  82450
# 73859    5 g sukker/l                              Irish Red Ale
# 73860                                               American IPA
#
# [73861 rows x 8 columns]

# %%
#replace missing values with preceding value

# %%
df_mis_ffill=df_miss.fillna(method='ffill')

# %%
df_mis_ffill
# Out:
#        BoilGravity  MashThickness  PitchRate  PrimaryTemp PrimingMethod  \
# 0            1.038            NaN        NaN        17.78    corn sugar
# 1            1.070            NaN        NaN        17.78    corn sugar
# 2            1.070            NaN        NaN        17.78    corn sugar
# 3            1.070            NaN        NaN        17.78    corn sugar
# 4            1.050            NaN        NaN        19.00    Sukkerlake
# ...            ...            ...        ...          ...           ...
# 73856        1.060            3.0       1.25        20.00    Corn Sugar
# 73857        1.034            3.0       0.50        22.00    Corn Sugar
# 73858        1.041            3.0       0.35        17.00       sucrose
# 73859        1.043            3.0       0.35        18.00    Sukkerlake
# 73860        1.056            3.0       0.35        18.00    Sukkerlake
#
#         PrimingAmount   UserId                               Style
# 0              4.5 oz    116.0                           Cream Ale
# 1              4.5 oz    955.0  Holiday/Winter Special Spiced Beer
# 2              4.5 oz    955.0                        American IPA
# 3              4.5 oz    955.0                        American IPA
# 4      6-7 g sukker/l  18325.0                   Belgian Blond Ale
# ...               ...      ...                                 ...
# 73856        70 grams  59658.0                  British Strong Ale
# 73857        70 grams  59658.0              Specialty IPA: Rye IPA
# 73858           140 g  82450.0              Specialty IPA: Rye IPA
# 73859    5 g sukker/l  82450.0                       Irish Red Ale
# 73860    5 g sukker/l  82450.0                        American IPA
#
# [73861 rows x 8 columns]

# %%
#replace missing values with succeeding value

# %%
df_mis_bfill=df_miss.fillna(method='backfill')

# %%
df_mis_bfill
# Out:
#        BoilGravity  MashThickness  PitchRate  PrimaryTemp PrimingMethod  \
# 0            1.038            1.4       1.00        17.78    corn sugar
# 1            1.070            1.4       1.00        19.00    Sukkerlake
# 2            1.050            1.4       1.00        19.00    Sukkerlake
# 3            1.050            1.4       1.00        19.00    Sukkerlake
# 4            1.050            1.4       1.00        19.00    Sukkerlake
# ...            ...            ...        ...          ...           ...
# 73856        1.060            3.0       1.25        20.00       sucrose
# 73857        1.034            NaN       0.50        22.00       sucrose
# 73858        1.041            NaN       0.35        17.00       sucrose
# 73859        1.043            NaN        NaN        18.00    Sukkerlake
# 73860        1.056            NaN        NaN        18.00           NaN
#
#         PrimingAmount   UserId                               Style
# 0              4.5 oz    116.0                           Cream Ale
# 1      6-7 g sukker/l    955.0  Holiday/Winter Special Spiced Beer
# 2      6-7 g sukker/l  18325.0                        American IPA
# 3      6-7 g sukker/l  18325.0                        American IPA
# 4      6-7 g sukker/l  18325.0                   Belgian Blond Ale
# ...               ...      ...                                 ...
# 73856           140 g  59658.0                  British Strong Ale
# 73857           140 g  82450.0              Specialty IPA: Rye IPA
# 73858           140 g  82450.0                       Irish Red Ale
# 73859    5 g sukker/l      NaN                       Irish Red Ale
# 73860             NaN      NaN                        American IPA
#
# [73861 rows x 8 columns]

# %%
# replace columns with BoilGravity=1.9,MashThickness=4,Style=other

# %%
dic={"BoilGravity" : "1.9" ,"MashThickness" : "4","Style" :"other"}

# %%
df_mis_dic=df_miss.fillna(value=dic)

# %%
df_mis_dic
# Out:
#       BoilGravity MashThickness  PitchRate  PrimaryTemp PrimingMethod  \
# 0           1.038             4        NaN        17.78    corn sugar
# 1            1.07             4        NaN          NaN           NaN
# 2             1.9             4        NaN          NaN           NaN
# 3             1.9             4        NaN          NaN           NaN
# 4            1.05             4        NaN        19.00    Sukkerlake
# ...           ...           ...        ...          ...           ...
# 73856        1.06             3       1.25        20.00           NaN
# 73857       1.034             4       0.50        22.00           NaN
# 73858       1.041             4       0.35        17.00       sucrose
# 73859       1.043             4        NaN        18.00    Sukkerlake
# 73860       1.056             4        NaN        18.00           NaN
#
#         PrimingAmount   UserId                               Style
# 0              4.5 oz    116.0                           Cream Ale
# 1                 NaN    955.0  Holiday/Winter Special Spiced Beer
# 2                 NaN      NaN                        American IPA
# 3                 NaN      NaN                        American IPA
# 4      6-7 g sukker/l  18325.0                   Belgian Blond Ale
# ...               ...      ...                                 ...
# 73856             NaN  59658.0                  British Strong Ale
# 73857             NaN      NaN              Specialty IPA: Rye IPA
# 73858           140 g  82450.0                               other
# 73859    5 g sukker/l      NaN                       Irish Red Ale
# 73860             NaN      NaN                        American IPA
#
# [73861 rows x 8 columns]

# %%
#replace missing values with Mean value
#sklearn. SimpleImputer(*, missing_values=''/nan, strategy='mean/median/most_frequent/constant', fill_value=None, verbose=0, copy=True, add_indicator=False)

# %%
from sklearn.impute import SimpleImputer

# %%
imp_mean=SimpleImputer(missing_values=np.nan ,strategy='mean')

# %%
imp_df=imp_mean.fit_tran

# %%
#replace missing values with Median value

# %%
#replace missing values with Mode value

# %%
arr=np.array([[1,2,3,4,5,6,7],[10,20,30,40,50,60,70]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5a8df27631dc> in <module>
# ----> 1 arr=np.array([[1,2,3,4,5,6,7],[10,20,30,40,50,60,70]])
#
# NameError: name 'np' is not defined

# %%
arr
# Out:
# array([[ 1,  2,  3,  4,  5,  6,  7],
#        [10, 20, 30, 40, 50, 60, 70]])

# %%
from sklearn.impute import SimpleImputer

# %%
im_mean=SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
imp_df=im_mean.fit_transform(im_mean.fit_transform(arr))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-047cf8324316> in <module>
# ----> 1 imp_df=im_mean.fit_transform(im_mean.fit_transform(arr))
#
# NameError: name 'im_mean' is not defined
